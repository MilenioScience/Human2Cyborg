# %%
import os
import numpy
import torch
import time as timer
from PIL import Image
import numpy as np
import torch
from torch import nn
from torch import optim
from skimage.util import random_noise

from torchvision import datasets
import torchvision.transforms as T
import torchvision.utils as vutils

import res.viz_utils as vu
from res.plot_lib import set_default

set_default()
from torch.utils.data import Dataset, DataLoader
from torch.utils.data import TensorDataset,DataLoader
from torch.nn import Module, Sequential, Conv2d, ConvTranspose2d, LeakyReLU, BatchNorm2d, ReLU, Tanh, Sigmoid, BCELoss
dev = 'cuda:0' if torch.cuda.is_available() == True else 'cpu'
device = torch.device(dev)
BATCH_SIZE = 64
NUM_EPOCH = 500
IMAGE_SIZE = 64
NUM_WORKERS = 2
DAY = '12may_newest'

# %%
# !pip install scikit-image
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: scikit-image in /home/jupyter-23522035/.local/lib/python3.7/site-packages (0.19.3)
# Requirement already satisfied: networkx>=2.2 in /home/jupyter-23522035/.local/lib/python3.7/site-packages (from scikit-image) (2.6.3)
# Requirement already satisfied: pillow!=7.1.0,!=7.1.1,!=8.3.0,>=6.1.0 in /home/jupyter-23522035/.local/lib/python3.7/site-packages (from scikit-image) (9.5.0)
# Requirement already satisfied: numpy>=1.17.0 in /opt/tljh/user/lib/python3.7/site-packages (from scikit-image) (1.21.4)
# Requirement already satisfied: tifffile>=2019.7.26 in /home/jupyter-23522035/.local/lib/python3.7/site-packages (from scikit-image) (2021.11.2)
# Requirement already satisfied: PyWavelets>=1.1.1 in /home/jupyter-23522035/.local/lib/python3.7/site-packages (from scikit-image) (1.3.0)
# Requirement already satisfied: packaging>=20.0 in /opt/tljh/user/lib/python3.7/site-packages (from scikit-image) (20.8)
# Requirement already satisfied: imageio>=2.4.1 in /home/jupyter-23522035/.local/lib/python3.7/site-packages (from scikit-image) (2.28.1)
# Requirement already satisfied: scipy>=1.4.1 in /opt/tljh/user/lib/python3.7/site-packages (from scikit-image) (1.7.2)
# Requirement already satisfied: pyparsing>=2.0.2 in /opt/tljh/user/lib/python3.7/site-packages (from packaging>=20.0->scikit-image) (2.4.7)

# %%
ls
# Out:
# AttentionGAN/            DCGAN/                    train_net_generator.ipynb
# cyborg_images_32x32.npz  Human_Cyborg_Data/        Untitled.ipynb
# cyborg_images_64x64.npz  instancenormalization.py
# CycleGAN/                res/

# %%
def init_weights(m):
    if type(m) == ConvTranspose2d:
        nn.init.normal_(m.weight, 0.0, 0.02)
    elif type(m) == BatchNorm2d:
        nn.init.normal_(m.weight, 1.0, 0.02)
        nn.init.constant_(m.bias, 0)

# %%
path_gambar = "Human_Cyborg_Data"
files_gambar = os.listdir(path_gambar)

# %%
path_gambar
# Out:
# 'Human_Cyborg_Data'

# %%
def transformimg(file,dir_data):
    img = Image.open(dir_data+'/'+file)
    img = img.convert('RGB')
    img = img.resize((64,64))
    img = np.asarray(img)/255
    X_train = np.array(img)
    return X_train

# %%
file_jpg = [file for file in files_gambar if file[-4:] == ".jpg"]

# %%
X = []
y = []
for file in file_jpg:
    arr_jpg = transformimg(file,path_gambar)
    X.append(arr_jpg)
    y.append(int(file[0])) 
X = np.array(X)
y = np.array(y)
X_train = torch.from_numpy(X)
label = torch.from_numpy(y)

# %%
X_train.shape
# Out:
# torch.Size([37, 64, 64, 3])

# %%
y.shape
# Out:
# (37,)

# %%
X_train = np.transpose( # imp step to convert image size from (7312, 32,32,3) to (7312, 3,32,32)
    X_train, # imp step to convert double -&gt; float (by default numpy input uses double as data type)
    (0,3,1,2) # tuple to describe how to rearrange the dimensions
    )
X_train.shape
# Out:
# torch.Size([37, 3, 64, 64])

# %%
dataset = TensorDataset(X_train, label)
data_loader = DataLoader(dataset, batch_size = 16, shuffle = True)

# %%
for batch_idx, (X,label) in enumerate(data_loader):
    print((X,label))

# %%
class Generator(Module):
    def __init__(self,ngpu=0):
 
        # calling constructor of parent class
        super().__init__()
        self.ngpu=ngpu
 
        self.gen = Sequential(
          ConvTranspose2d(in_channels = 100, out_channels = 512 , kernel_size = 4, stride = 1, padding = 0, bias = False),
          # the output from the above will be b_size ,512, 4,4
          BatchNorm2d(num_features = 512), # From an input of size (b_size, C, H, W), pick num_features = C
          ReLU(inplace = True),
 
          ConvTranspose2d(in_channels = 512, out_channels = 256 , kernel_size = 4, stride = 2, padding = 1, bias = False),
          # the output from the above will be b_size ,256, 8,8
          BatchNorm2d(num_features = 256),
          ReLU(inplace = True),
 
          ConvTranspose2d(in_channels = 256, out_channels = 128 , kernel_size = 4, stride = 2, padding = 1, bias = False),
          # the output from the above will be b_size ,128, 16,16
          BatchNorm2d(num_features = 128),
          ReLU(inplace = True),
          
          ConvTranspose2d(in_channels = 128, out_channels = 64 , kernel_size = 4, stride = 2, padding = 1, bias = False),
          # the output from the above will be b_size ,128, 16,16
          BatchNorm2d(num_features = 64),
          ReLU(inplace = True),  
 
          ConvTranspose2d(in_channels = 64, out_channels = 3 , kernel_size = 4, stride = 2, padding = 1, bias = False),
          # the output from the above will be b_size ,3, 32,32
          Tanh()
         
        )
 
    def forward(self, input):
        if input.is_cuda and self.ngpu > 1:
            output = nn.parallel.data_parallel(self.gen, input, range(self.ngpu))
        else:
            output = self.gen(input)
        return output
    
# class ExampleGenerator(Module):
 
#       def __init__(self):
#           # calling constructor of parent class
#           super().__init__()
#           self.gen = Sequential(
#               ConvTranspose2d(
#               in_channels = 100, 
#               out_channels = 512 , 
#               kernel_size = 4, 
#               stride = 1, 
#               padding = 0, 
#               bias = False)
#               )
 
#       def forward(self, input):
#            return self.gen(input)
 
# # defining class object
# ex_gen = ExampleGenerator()
 
# # defining random input for the model: b_size = 2 here
# t = torch.randn(2, 100, 1, 1)
 
# # checking the shape of the output from model
# ex_gen(t).shape

# %%
class Discriminator(Module):
    def __init__(self,ngpu=0):
 
        super().__init__()
        self.ngpu = ngpu
        self.dis = Sequential(
 
            # input is (3, 32, 32)
            Conv2d(in_channels = 3, out_channels = 64, kernel_size = 4, stride = 2, padding = 1, bias=False),
            # ouput from above layer is b_size, 32, 16, 16
            LeakyReLU(0.2, inplace=True),
 
            Conv2d(in_channels = 64, out_channels = 64*2, kernel_size = 4, stride = 2, padding = 1, bias=False),
            # ouput from above layer is b_size, 32*2, 8, 8
            BatchNorm2d(64 * 2),
            LeakyReLU(0.2, inplace=True),
 
            Conv2d(in_channels = 64*2, out_channels = 64*4, kernel_size = 4, stride = 2, padding = 1, bias=False),
            # ouput from above layer is b_size, 32*4, 4, 4
            BatchNorm2d(64 * 4),
            LeakyReLU(0.2, inplace=True),
 
            Conv2d(in_channels = 64*4, out_channels = 64*8, kernel_size = 4, stride = 2, padding = 1, bias=False),
            # ouput from above layer is b_size, 256, 2, 2
            # NOTE: spatial size of this layer is 2x2, hence in the final layer, the kernel size must be 2 instead (or smaller than) 4
            BatchNorm2d(64 * 8),
            LeakyReLU(0.2, inplace=True),
 
            Conv2d(in_channels = 64*8, out_channels = 1, kernel_size = 4, stride = 1, padding = 0, bias=False),
            # ouput from above layer is b_size, 1, 1, 1
            Sigmoid()
        )
     
    def forward(self, input):
        if input.is_cuda and self.ngpu > 1:
            output = nn.parallel.data_parallel(self.dis, input, range(self.ngpu))
        else:
            output = self.dis(input)
        return output.view(-1, 1).squeeze(1)

# %%
def init_weights(m):
    if type(m) == ConvTranspose2d:
        nn.init.normal_(m.weight, 0.0, 0.02)
    elif type(m) == BatchNorm2d:
        nn.init.normal_(m.weight, 1.0, 0.02)
        nn.init.constant_(m.bias, 0)
pretrained_dis_model_path = 'DCGAN/output/ckpt_output/dcgan_dis_z100_ep500_12may_newest.pth'
pretrained_gen_model_path = 'DCGAN/output/ckpt_output/dcgan_gen_z100_ep500_12may_newest.pth'
netG = Generator(ngpu=2).to(device)
netD = Discriminator(ngpu=2).to(device)
netD.apply(init_weights)
netG.apply(init_weights)
netD.load_state_dict(torch.load(pretrained_dis_model_path))
netG.load_state_dict(torch.load(pretrained_gen_model_path))
print(netG)
print(netD)
optimizerD = optim.Adam(netD.parameters(), lr=2e-4, betas=(0.5, 0.999))
optimizerG = optim.Adam(netG.parameters(), lr=2e-4, betas=(0.5, 0.999))
criterion = nn.BCELoss()
# Out:
# Generator(
#   (gen): Sequential(
#     (0): ConvTranspose2d(100, 512, kernel_size=(4, 4), stride=(1, 1), bias=False)
#     (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU(inplace=True)
#     (3): ConvTranspose2d(512, 256, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (4): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (5): ReLU(inplace=True)
#     (6): ConvTranspose2d(256, 128, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (7): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (8): ReLU(inplace=True)
#     (9): ConvTranspose2d(128, 64, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (10): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (11): ReLU(inplace=True)
#     (12): ConvTranspose2d(64, 3, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (13): Tanh()
#   )
# )
# Discriminator(
#   (dis): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (1): LeakyReLU(negative_slope=0.2, inplace=True)
#     (2): Conv2d(64, 128, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (3): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (4): LeakyReLU(negative_slope=0.2, inplace=True)
#     (5): Conv2d(128, 256, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (6): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (7): LeakyReLU(negative_slope=0.2, inplace=True)
#     (8): Conv2d(256, 512, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (9): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (10): LeakyReLU(negative_slope=0.2, inplace=True)
#     (11): Conv2d(512, 1, kernel_size=(4, 4), stride=(1, 1), bias=False)
#     (12): Sigmoid()
#   )
# )

# %%
gname = "dcgan_gen" 
MODEL_DIR = 'DCGAN/output/ckpt_output/'
SAMPLE_DIR = 'DCGAN/output/image_gen'
fixed_noise = torch.randn(64, 100, 1, 1, device=device)
real_label = 1
fake_label = 0
gen_path = os.path.join(MODEL_DIR, f"{gname}_z{100}_ep{NUM_EPOCH}_{DAY}_newest.pth")

dname = "dcgan_dis" 
dis_path = os.path.join(MODEL_DIR, f"{dname}_z{100}_ep{NUM_EPOCH}_{DAY}_newest.pth")
for epoch in range(NUM_EPOCH):
    
    for batch_idx, (X, _) in enumerate(data_loader):
        start_t = timer.time()
        ############################
        #  Update D network: maximize log(D(x)) + log(1 - D(G(z)))
        ###########################

        # Train with real image
        netD.zero_grad()
        real_cpu = X
        real_cpu = real_cpu.float()
        real_cpu = real_cpu.to(device)
        batch_size = real_cpu.size(0)
        label = torch.full(
            (batch_size,), real_label,
            dtype=real_cpu.dtype, 
            device=device
        )

        output = netD(real_cpu)
        errD_real = criterion(output, label)
        errD_real.backward()
        D_x = output.mean().item()

        # Train with fake image
        noise = torch.randn(batch_size, 100, 1, 1, device=device)
        fake = netG(noise)
        label.fill_(fake_label)
        output = netD(fake.detach())
        errD_fake = criterion(output, label)
        errD_fake.backward()
        D_G_z1 = output.mean().item()

        errD = errD_real + errD_fake
        optimizerD.step()

        ############################
        # Update G network: minimize log(D(x)) + log(1 - D(G(z)))
        ###########################
        netG.zero_grad()
        label.fill_(real_label) # fake labels are real for generator cost
        output = netD(fake)
        errG = criterion(output, label)
        errG.backward()
        D_G_z2 = output.mean().item()
        optimizerG.step()
        elapsed_t = timer.time() - start_t

        if batch_idx % 100 == 0:
            print(f'[{epoch+1}/{NUM_EPOCH}] [{batch_idx} / {len(data_loader)}] Loss_D: {errD.item():.4f} Loss_G: {errG.item():.4f} D(x): {D_x:.4f} D(G(z)): {D_G_z1:.4f} / {D_G_z2:.4f} Elapsed: {elapsed_t:.2f} secs')
            vutils.save_image(real_cpu, f'{SAMPLE_DIR}/real_samples_epoch-{epoch+1}_batch-{batch_idx}.png', normalize=True)
            fake = netG(fixed_noise)
            vutils.save_image(fake.detach(), f'{SAMPLE_DIR}/fake_samples_epoch-{epoch+1}_batch-{batch_idx}.png', normalize=True)

            # Checkpointing
            torch.save(netD.state_dict(), dis_path)
            print(f" --- Discriminator model stored in {dis_path} ---")

            torch.save(netG.state_dict(), gen_path)
            print(f" --- Generator model stored in {gen_path} ---")
# Out:
# [1/500] [0 / 3] Loss_D: 0.3786 Loss_G: 10.9816 D(x): 0.8010 D(G(z)): 0.0000 / 0.0021 Elapsed: 0.92 secs
#  --- Discriminator model stored in DCGAN/output/ckpt_output/dcgan_dis_z100_ep500_12may_newest_newest.pth ---
#  --- Generator model stored in DCGAN/output/ckpt_output/dcgan_gen_z100_ep500_12may_newest_newest.pth ---
# [2/500] [0 / 3] Loss_D: 0.0019 Loss_G: 9.9424 D(x): 0.9998 D(G(z)): 0.0017 / 0.0011 Elapsed: 0.29 secs
#  --- Discriminator model stored in DCGAN/output/ckpt_output/dcgan_dis_z100_ep500_12may_newest_newest.pth ---
#  --- Generator model stored in DCGAN/output/ckpt_output/dcgan_gen_z100_ep500_12may_newest_newest.pth ---
# [3/500] [0 / 3] Loss_D: 0.0074 Loss_G: 8.3174 D(x): 0.9981 D(G(z)): 0.0055 / 0.0008 Elapsed: 0.28 secs
#  --- Discriminator model stored in DCGAN/output/ckpt_output/dcgan_dis_z100_ep500_12may_newest_newest.pth ---
#  --- Generator model stored in DCGAN/output/ckpt_output/dcgan_gen_z100_ep500_12may_newest_newest.pth ---
# [4/500] [0 / 3] Loss_D: 0.0041 Loss_G: 8.9623 D(x): 0.9971 D(G(z)): 0.0012 / 0.0003 Elapsed: 0.23 secs
#  --- Discriminator model stored in DCGAN/output/ckpt_output/dcgan_dis_z100_ep500_12may_newest_newest.pth ---
#  --- Generator model stored in DCGAN/output/ckpt_output/dcgan_gen_z100_ep500_12may_newest_newest.pth ---
# [5/500] [0 / 3] Loss_D: 0.0199 Loss_G: 9.8504 D(x): 0.9976 D(G(z)): 0.0170 / 0.0001 Elapsed: 0.22 secs
#  --- Discriminator model stored in DCGAN/output/ckpt_output/dcgan_dis_z100_ep500_12may_newest_newest.pth ---
#  --- Generator model stored in DCGAN/output/ckpt_output/dcgan_gen_z100_ep500_12may_newest_newest.pth ---
# [6/500] [0 / 3] Loss_D: 0.2153 Loss_G: 13.8844 D(x): 0.9999 D(G(z)): 0.1748 / 0.0000 Elapsed: 0.29 secs
#  --- Discriminator model stored in DCGAN/output/ckpt_output/dcgan_dis_z100_ep500_12may_newest_newest.pth ---
#  --- Generator model stored in DCGAN/output/ckpt_output/dcgan_gen_z100_ep500_12may_newest_newest.pth ---
# [7/500] [0 / 3] Loss_D: 0.0064 Loss_G: 11.4410 D(x): 0.9939 D(G(z)): 0.0002 / 0.0004 Elapsed: 0.29 secs
#  --- Discriminator model stored in DCGAN/output/ckpt_output/dcgan_dis_z100_ep500_12may_newest_newest.pth ---
#  --- Generator model stored in DCGAN/output/ckpt_output/dcgan_gen_z100_ep500_12may_newest_newest.pth ---
# [8/500] [0 / 3] Loss_D: 0.0043 Loss_G: 11.7762 D(x): 0.9980 D(G(z)): 0.0023 / 0.0001 Elapsed: 0.30 secs
#  --- Discriminator model stored in DCGAN/output/ckpt_output/dcgan_dis_z100_ep500_12may_newest_newest.pth ---
#  --- Generator model stored in DCGAN/output/ckpt_output/dcgan_gen_z100_ep500_12may_newest_newest.pth ---
# [9/500] [0 / 3] Loss_D: 0.0549 Loss_G: 9.5855 D(x): 0.9966 D(G(z)): 0.0478 / 0.0002 Elapsed: 0.21 secs
#  --- Discriminator model stored in DCGAN/output/ckpt_output/dcgan_dis_z100_ep500_12may_newest_newest.pth ---
#  --- Generator model stored in DCGAN/output/ckpt_output/dcgan_gen_z100_ep500_12may_newest_newest.pth ---
# [10/500] [0 / 3] Loss_D: 1.4392 Loss_G: 21.9889 D(x): 0.9999 D(G(z)): 0.6800 / 0.0000 Elapsed: 0.23 secs
#  --- Discriminator model stored in DCGAN/output/ckpt_output/dcgan_dis_z100_ep500_12may_newest_newest.pth ---
#  --- Generator model stored in DCGAN/output/ckpt_output/dcgan_gen_z100_ep500_12may_newest_newest.pth ---
# [11/500] [0 / 3] Loss_D: 0.0846 Loss_G: 18.6560 D(x): 0.9281 D(G(z)): 0.0000 / 0.0000 Elapsed: 0.23 secs
#  --- Discriminator model stored in DCGAN/output/ckpt_output/dcgan_dis_z100_ep500_12may_newest_newest.pth ---
#  --- Generator model stored in DCGAN/output/ckpt_output/dcgan_gen_z100_ep500_12may_newest_newest.pth ---
# [12/500] [0 / 3] Loss_D: 0.0681 Loss_G: 6.6337 D(x): 0.9997 D(G(z)): 0.0588 / 0.0038 Elapsed: 0.30 secs
#  --- Discriminator model stored in DCGAN/output/ckpt_output/dcgan_dis_z100_ep500_12may_newest_newest.pth ---
#  --- Generator model stored in DCGAN/output/ckpt_output/dcgan_gen_z100_ep500_12may_newest_newest.pth ---
# [13/500] [0 / 3] Loss_D: 0.0436 Loss_G: 7.5284 D(x): 0.9807 D(G(z)): 0.0199 / 0.0009 Elapsed: 0.21 secs
#  --- Discriminator model stored in DCGAN/output/ckpt_output/dcgan_dis_z100_ep500_12may_newest_newest.pth ---
#  --- Generator model stored in DCGAN/output/ckpt_output/dcgan_gen_z100_ep500_12may_newest_newest.pth ---
# [14/500] [0 / 3] Loss_D: 0.0760 Loss_G: 7.1014 D(x): 0.9825 D(G(z)): 0.0535 / 0.0012 Elapsed: 0.23 secs
#  --- Discriminator model stored in DCGAN/output/ckpt_output/dcgan_dis_z100_ep500_12may_newest_newest.pth ---
#  --- Generator model stored in DCGAN/output/ckpt_output/dcgan_gen_z100_ep500_12may_newest_newest.pth ---
# [15/500] [0 / 3] Loss_D: 0.0155 Loss_G: 7.0750 D(x): 0.9938 D(G(z)): 0.0089 / 0.0021 Elapsed: 0.20 secs
#  --- Discriminator model stored in DCGAN/output/ckpt_output/dcgan_dis_z100_ep500_12may_newest_newest.pth ---
#  --- Generator model stored in DCGAN/output/ckpt_output/dcgan_gen_z100_ep500_12may_newest_newest.pth ---
# [16/500] [0 / 3] Loss_D: 0.0775 Loss_G: 7.6269 D(x): 0.9991 D(G(z)): 0.0706 / 0.0010 Elapsed: 0.21 secs
#  --- Discriminator model stored in DCGAN/output/ckpt_output/dcgan_dis_z100_ep500_12may_newest_newest.pth ---
#  --- Generator model stored in DCGAN/output/ckpt_output/dcgan_gen_z100_ep500_12may_newest_newest.pth ---
# [17/500] [0 / 3] Loss_D: 0.0177 Loss_G: 6.6409 D(x): 0.9952 D(G(z)): 0.0126 / 0.0024 Elapsed: 0.24 secs
#  --- Discriminator model stored in DCGAN/output/ckpt_output/dcgan_dis_z100_ep500_12may_newest_newest.pth ---
#  --- Generator model stored in DCGAN/output/ckpt_output/dcgan_gen_z100_ep500_12may_newest_newest.pth ---
# [18/500] [0 / 3] Loss_D: 0.0379 Loss_G: 7.6832 D(x): 0.9979 D(G(z)): 0.0344 / 0.0011 Elapsed: 0.30 secs
#  --- Discriminator model stored in DCGAN/output/ckpt_output/dcgan_dis_z100_ep500_12may_newest_newest.pth ---
#  --- Generator model stored in DCGAN/output/ckpt_output/dcgan_gen_z100_ep500_12may_newest_newest.pth ---
# [19/500] [0 / 3] Loss_D: 0.0483 Loss_G: 7.0720 D(x): 0.9967 D(G(z)): 0.0433 / 0.0028 Elapsed: 0.28 secs
#  --- Discriminator model stored in DCGAN/output/ckpt_output/dcgan_dis_z100_ep500_12may_newest_newest.pth ---
#  --- Generator model stored in DCGAN/output/ckpt_output/dcgan_gen_z100_ep500_12may_newest_newest.pth ---
# [20/500] [0 / 3] Loss_D: 0.0159 Loss_G: 6.3568 D(x): 0.9960 D(G(z)): 0.0117 / 0.0033 Elapsed: 0.22 secs
#  --- Discriminator model stored in DCGAN/output/ckpt_output/dcgan_dis_z100_ep500_12may_newest_newest.pth ---
#  --- Generator model stored in DCGAN/output/ckpt_output/dcgan_gen_z100_ep500_12may_newest_newest.pth ---
# [21/500] [0 / 3] Loss_D: 0.0338 Loss_G: 7.7050 D(x): 0.9963 D(G(z)): 0.0290 / 0.0011 Elapsed: 0.23 secs
#  --- Discriminator model stored in DCGAN/output/ckpt_output/dcgan_dis_z100_ep500_12may_newest_newest.pth ---
#  --- Generator model stored in DCGAN/output/ckpt_output/dcgan_gen_z100_ep500_12may_newest_newest.pth ---
# [22/500] [0 / 3] Loss_D: 0.0120 Loss_G: 7.9338 D(x): 0.9938 D(G(z)): 0.0057 / 0.0009 Elapsed: 0.30 secs
#  --- Discriminator model stored in DCGAN/output/ckpt_output/dcgan_dis_z100_ep500_12may_newest_newest.pth ---
#  --- Generator model stored in DCGAN/output/ckpt_output/dcgan_gen_z100_ep500_12may_newest_newest.pth ---
# [23/500] [0 / 3] Loss_D: 0.0187 Loss_G: 6.6977 D(x): 0.9964 D(G(z)): 0.0149 / 0.0023 Elapsed: 0.19 secs
#  --- Discriminator model stored in DCGAN/output/ckpt_output/dcgan_dis_z100_ep500_12may_newest_newest.pth ---
#  --- Generator model stored in DCGAN/output/ckpt_output/dcgan_gen_z100_ep500_12may_newest_newest.pth ---
# [24/500] [0 / 3] Loss_D: 0.0258 Loss_G: 7.0437 D(x): 0.9942 D(G(z)): 0.0194 / 0.0046 Elapsed: 0.22 secs
#  --- Discriminator model stored in DCGAN/output/ckpt_output/dcgan_dis_z100_ep500_12may_newest_newest.pth ---
#  --- Generator model stored in DCGAN/output/ckpt_output/dcgan_gen_z100_ep500_12may_newest_newest.pth ---
# [25/500] [0 / 3] Loss_D: 0.0088 Loss_G: 9.3157 D(x): 0.9917 D(G(z)): 0.0003 / 0.0001 Elapsed: 0.22 secs
#  --- Discriminator model stored in DCGAN/output/ckpt_output/dcgan_dis_z100_ep500_12may_newest_newest.pth ---
#  --- Generator model stored in DCGAN/output/ckpt_output/dcgan_gen_z100_ep500_12may_newest_newest.pth ---
# [26/500] [0 / 3] Loss_D: 0.0072 Loss_G: 7.7831 D(x): 0.9977 D(G(z)): 0.0048 / 0.0010 Elapsed: 0.21 secs
#  --- Discriminator model stored in DCGAN/output/ckpt_output/dcgan_dis_z100_ep500_12may_newest_newest.pth ---
#  --- Generator model stored in DCGAN/output/ckpt_output/dcgan_gen_z100_ep500_12may_newest_newest.pth ---
# [27/500] [0 / 3] Loss_D: 0.0073 Loss_G: 8.9863 D(x): 0.9954 D(G(z)): 0.0026 / 0.0002 Elapsed: 0.29 secs
#  --- Discriminator model stored in DCGAN/output/ckpt_output/dcgan_dis_z100_ep500_12may_newest_newest.pth ---
#  --- Generator model stored in DCGAN/output/ckpt_output/dcgan_gen_z100_ep500_12may_newest_newest.pth ---
# [28/500] [0 / 3] Loss_D: 0.2683 Loss_G: 21.6470 D(x): 0.9977 D(G(z)): 0.2003 / 0.0000 Elapsed: 0.21 secs
#  --- Discriminator model stored in DCGAN/output/ckpt_output/dcgan_dis_z100_ep500_12may_newest_newest.pth ---
#  --- Generator model stored in DCGAN/output/ckpt_output/dcgan_gen_z100_ep500_12may_newest_newest.pth ---
# [29/500] [0 / 3] Loss_D: 0.0065 Loss_G: 14.1823 D(x): 0.9937 D(G(z)): 0.0000 / 0.0000 Elapsed: 0.22 secs
#  --- Discriminator model stored in DCGAN/output/ckpt_output/dcgan_dis_z100_ep500_12may_newest_newest.pth ---
#  --- Generator model stored in DCGAN/output/ckpt_output/dcgan_gen_z100_ep500_12may_newest_newest.pth ---
# [30/500] [0 / 3] Loss_D: 0.0948 Loss_G: 11.8731 D(x): 0.9982 D(G(z)): 0.0804 / 0.0002 Elapsed: 0.21 secs
#  --- Discriminator model stored in DCGAN/output/ckpt_output/dcgan_dis_z100_ep500_12may_newest_newest.pth ---
#  --- Generator model stored in DCGAN/output/ckpt_output/dcgan_gen_z100_ep500_12may_newest_newest.pth ---
# [31/500] [0 / 3] Loss_D: 0.0378 Loss_G: 6.1286 D(x): 0.9997 D(G(z)): 0.0345 / 0.0063 Elapsed: 0.28 secs
#  --- Discriminator model stored in DCGAN/output/ckpt_output/dcgan_dis_z100_ep500_12may_newest_newest.pth ---
#  --- Generator model stored in DCGAN/output/ckpt_output/dcgan_gen_z100_ep500_12may_newest_newest.pth ---
# [32/500] [0 / 3] Loss_D: 0.0013 Loss_G: 16.3777 D(x): 0.9988 D(G(z)): 0.0001 / 0.0001 Elapsed: 0.23 secs
#  --- Discriminator model stored in DCGAN/output/ckpt_output/dcgan_dis_z100_ep500_12may_newest_newest.pth ---
#  --- Generator model stored in DCGAN/output/ckpt_output/dcgan_gen_z100_ep500_12may_newest_newest.pth ---
# [33/500] [0 / 3] Loss_D: 0.0253 Loss_G: 8.8010 D(x): 0.9997 D(G(z)): 0.0242 / 0.0003 Elapsed: 0.28 secs
#  --- Discriminator model stored in DCGAN/output/ckpt_output/dcgan_dis_z100_ep500_12may_newest_newest.pth ---
#  --- Generator model stored in DCGAN/output/ckpt_output/dcgan_gen_z100_ep500_12may_newest_newest.pth ---
# [34/500] [0 / 3] Loss_D: 0.2107 Loss_G: 16.8559 D(x): 0.9952 D(G(z)): 0.1622 / 0.0000 Elapsed: 0.31 secs
#  --- Discriminator model stored in DCGAN/output/ckpt_output/dcgan_dis_z100_ep500_12may_newest_newest.pth ---
#  --- Generator model stored in DCGAN/output/ckpt_output/dcgan_gen_z100_ep500_12may_newest_newest.pth ---
# [35/500] [0 / 3] Loss_D: 0.0160 Loss_G: 9.6283 D(x): 0.9995 D(G(z)): 0.0144 / 0.0180 Elapsed: 0.28 secs
#  --- Discriminator model stored in DCGAN/output/ckpt_output/dcgan_dis_z100_ep500_12may_newest_newest.pth ---
#  --- Generator model stored in DCGAN/output/ckpt_output/dcgan_gen_z100_ep500_12may_newest_newest.pth ---
# [36/500] [0 / 3] Loss_D: 0.0259 Loss_G: 13.9999 D(x): 0.9758 D(G(z)): 0.0000 / 0.0000 Elapsed: 0.23 secs
#  --- Discriminator model stored in DCGAN/output/ckpt_output/dcgan_dis_z100_ep500_12may_newest_newest.pth ---
#  --- Generator model stored in DCGAN/output/ckpt_output/dcgan_gen_z100_ep500_12may_newest_newest.pth ---
# [37/500] [0 / 3] Loss_D: 0.0066 Loss_G: 9.6541 D(x): 0.9970 D(G(z)): 0.0036 / 0.0003 Elapsed: 0.22 secs
#  --- Discriminator model stored in DCGAN/output/ckpt_output/dcgan_dis_z100_ep500_12may_newest_newest.pth ---
#  --- Generator model stored in DCGAN/output/ckpt_output/dcgan_gen_z100_ep500_12may_newest_newest.pth ---
# [38/500] [0 / 3] Loss_D: 0.0510 Loss_G: 8.4036 D(x): 0.9981 D(G(z)): 0.0452 / 0.0012 Elapsed: 0.28 secs
#  --- Discriminator model stored in DCGAN/output/ckpt_output/dcgan_dis_z100_ep500_12may_newest_newest.pth ---
#  --- Generator model stored in DCGAN/output/ckpt_output/dcgan_gen_z100_ep500_12may_newest_newest.pth ---
# [39/500] [0 / 3] Loss_D: 0.0507 Loss_G: 23.0624 D(x): 0.9592 D(G(z)): 0.0000 / 0.0000 Elapsed: 0.20 secs
#  --- Discriminator model stored in DCGAN/output/ckpt_output/dcgan_dis_z100_ep500_12may_newest_newest.pth ---
#  --- Generator model stored in DCGAN/output/ckpt_output/dcgan_gen_z100_ep500_12may_newest_newest.pth ---
# [40/500] [0 / 3] Loss_D: 0.0103 Loss_G: 14.1180 D(x): 0.9961 D(G(z)): 0.0062 / 0.0005 Elapsed: 0.29 secs
#  --- Discriminator model stored in DCGAN/output/ckpt_output/dcgan_dis_z100_ep500_12may_newest_newest.pth ---
#  --- Generator model stored in DCGAN/output/ckpt_output/dcgan_gen_z100_ep500_12may_newest_newest.pth ---
# [41/500] [0 / 3] Loss_D: 0.1219 Loss_G: 15.0558 D(x): 0.9149 D(G(z)): 0.0005 / 0.0001 Elapsed: 0.22 secs
#  --- Discriminator model stored in DCGAN/output/ckpt_output/dcgan_dis_z100_ep500_12may_newest_newest.pth ---
#  --- Generator model stored in DCGAN/output/ckpt_output/dcgan_gen_z100_ep500_12may_newest_newest.pth ---
# [42/500] [0 / 3] Loss_D: 0.0154 Loss_G: 7.3073 D(x): 0.9988 D(G(z)): 0.0140 / 0.0043 Elapsed: 0.30 secs
#  --- Discriminator model stored in DCGAN/output/ckpt_output/dcgan_dis_z100_ep500_12may_newest_newest.pth ---
#  --- Generator model stored in DCGAN/output/ckpt_output/dcgan_gen_z100_ep500_12may_newest_newest.pth ---
# [43/500] [0 / 3] Loss_D: 0.0202 Loss_G: 14.2810 D(x): 0.9803 D(G(z)): 0.0000 / 0.0000 Elapsed: 0.29 secs
#  --- Discriminator model stored in DCGAN/output/ckpt_output/dcgan_dis_z100_ep500_12may_newest_newest.pth ---
#  --- Generator model stored in DCGAN/output/ckpt_output/dcgan_gen_z100_ep500_12may_newest_newest.pth ---
# [44/500] [0 / 3] Loss_D: 1.8628 Loss_G: 20.5019 D(x): 0.9999 D(G(z)): 0.5837 / 0.0000 Elapsed: 0.29 secs
#  --- Discriminator model stored in DCGAN/output/ckpt_output/dcgan_dis_z100_ep500_12may_newest_newest.pth ---
#  --- Generator model stored in DCGAN/output/ckpt_output/dcgan_gen_z100_ep500_12may_newest_newest.pth ---
# [45/500] [0 / 3] Loss_D: 0.0998 Loss_G: 18.6192 D(x): 0.9296 D(G(z)): 0.0003 / 0.0005 Elapsed: 0.30 secs
#  --- Discriminator model stored in DCGAN/output/ckpt_output/dcgan_dis_z100_ep500_12may_newest_newest.pth ---
#  --- Generator model stored in DCGAN/output/ckpt_output/dcgan_gen_z100_ep500_12may_newest_newest.pth ---
# [46/500] [0 / 3] Loss_D: 0.0182 Loss_G: 8.5953 D(x): 0.9988 D(G(z)): 0.0165 / 0.0076 Elapsed: 0.30 secs
#  --- Discriminator model stored in DCGAN/output/ckpt_output/dcgan_dis_z100_ep500_12may_newest_newest.pth ---
#  --- Generator model stored in DCGAN/output/ckpt_output/dcgan_gen_z100_ep500_12may_newest_newest.pth ---
# [47/500] [0 / 3] Loss_D: 0.0597 Loss_G: 8.4658 D(x): 0.9958 D(G(z)): 0.0524 / 0.0009 Elapsed: 0.31 secs
#  --- Discriminator model stored in DCGAN/output/ckpt_output/dcgan_dis_z100_ep500_12may_newest_newest.pth ---
#  --- Generator model stored in DCGAN/output/ckpt_output/dcgan_gen_z100_ep500_12may_newest_newest.pth ---
# [48/500] [0 / 3] Loss_D: 0.0623 Loss_G: 7.5931 D(x): 0.9726 D(G(z)): 0.0288 / 0.0019 Elapsed: 0.28 secs
#  --- Discriminator model stored in DCGAN/output/ckpt_output/dcgan_dis_z100_ep500_12may_newest_newest.pth ---
#  --- Generator model stored in DCGAN/output/ckpt_output/dcgan_gen_z100_ep500_12may_newest_newest.pth ---
# [49/500] [0 / 3] Loss_D: 0.0496 Loss_G: 8.5676 D(x): 0.9633 D(G(z)): 0.0018 / 0.0008 Elapsed: 0.22 secs
#  --- Discriminator model stored in DCGAN/output/ckpt_output/dcgan_dis_z100_ep500_12may_newest_newest.pth ---
#  --- Generator model stored in DCGAN/output/ckpt_output/dcgan_gen_z100_ep500_12may_newest_newest.pth ---
# [50/500] [0 / 3] Loss_D: 1.2082 Loss_G: 22.9378 D(x): 0.9984 D(G(z)): 0.5632 / 0.0000 Elapsed: 0.20 secs
#  --- Discriminator model stored in DCGAN/output/ckpt_output/dcgan_dis_z100_ep500_12may_newest_newest.pth ---
#  --- Generator model stored in DCGAN/output/ckpt_output/dcgan_gen_z100_ep500_12may_newest_newest.pth ---
# [51/500] [0 / 3] Loss_D: 0.3201 Loss_G: 24.8953 D(x): 0.8896 D(G(z)): 0.0000 / 0.0000 Elapsed: 0.30 secs
#  --- Discriminator model stored in DCGAN/output/ckpt_output/dcgan_dis_z100_ep500_12may_newest_newest.pth ---
#  --- Generator model stored in DCGAN/output/ckpt_output/dcgan_gen_z100_ep500_12may_newest_newest.pth ---
# [52/500] [0 / 3] Loss_D: 0.0027 Loss_G: 20.1632 D(x): 0.9978 D(G(z)): 0.0004 / 0.0005 Elapsed: 0.20 secs
#  --- Discriminator model stored in DCGAN/output/ckpt_output/dcgan_dis_z100_ep500_12may_newest_newest.pth ---
#  --- Generator model stored in DCGAN/output/ckpt_output/dcgan_gen_z100_ep500_12may_newest_newest.pth ---
# [53/500] [0 / 3] Loss_D: 0.0090 Loss_G: 14.6929 D(x): 0.9995 D(G(z)): 0.0084 / 0.0059 Elapsed: 0.21 secs
#  --- Discriminator model stored in DCGAN/output/ckpt_output/dcgan_dis_z100_ep500_12may_newest_newest.pth ---
#  --- Generator model stored in DCGAN/output/ckpt_output/dcgan_gen_z100_ep500_12may_newest_newest.pth ---
# [54/500] [0 / 3] Loss_D: 0.0322 Loss_G: 10.1005 D(x): 0.9962 D(G(z)): 0.0270 / 0.0084 Elapsed: 0.20 secs
#  --- Discriminator model stored in DCGAN/output/ckpt_output/dcgan_dis_z100_ep500_12may_newest_newest.pth ---
#  --- Generator model stored in DCGAN/output/ckpt_output/dcgan_gen_z100_ep500_12may_newest_newest.pth ---
# [55/500] [0 / 3] Loss_D: 0.0339 Loss_G: 7.0031 D(x): 0.9971 D(G(z)): 0.0303 / 0.0081 Elapsed: 0.30 secs
#  --- Discriminator model stored in DCGAN/output/ckpt_output/dcgan_dis_z100_ep500_12may_newest_newest.pth ---
#  --- Generator model stored in DCGAN/output/ckpt_output/dcgan_gen_z100_ep500_12may_newest_newest.pth ---
# [56/500] [0 / 3] Loss_D: 0.0355 Loss_G: 7.6398 D(x): 0.9938 D(G(z)): 0.0272 / 0.0014 Elapsed: 0.23 secs
#  --- Discriminator model stored in DCGAN/output/ckpt_output/dcgan_dis_z100_ep500_12may_newest_newest.pth ---
#  --- Generator model stored in DCGAN/output/ckpt_output/dcgan_gen_z100_ep500_12may_newest_newest.pth ---
# [57/500] [0 / 3] Loss_D: 0.0843 Loss_G: 8.0811 D(x): 0.9877 D(G(z)): 0.0597 / 0.0006 Elapsed: 0.29 secs
#  --- Discriminator model stored in DCGAN/output/ckpt_output/dcgan_dis_z100_ep500_12may_newest_newest.pth ---
#  --- Generator model stored in DCGAN/output/ckpt_output/dcgan_gen_z100_ep500_12may_newest_newest.pth ---
# [58/500] [0 / 3] Loss_D: 0.0078 Loss_G: 6.9381 D(x): 0.9968 D(G(z)): 0.0046 / 0.0023 Elapsed: 0.30 secs
#  --- Discriminator model stored in DCGAN/output/ckpt_output/dcgan_dis_z100_ep500_12may_newest_newest.pth ---
#  --- Generator model stored in DCGAN/output/ckpt_output/dcgan_gen_z100_ep500_12may_newest_newest.pth ---
# [59/500] [0 / 3] Loss_D: 0.5999 Loss_G: 14.7521 D(x): 0.9996 D(G(z)): 0.3551 / 0.0000 Elapsed: 0.29 secs
#  --- Discriminator model stored in DCGAN/output/ckpt_output/dcgan_dis_z100_ep500_12may_newest_newest.pth ---
#  --- Generator model stored in DCGAN/output/ckpt_output/dcgan_gen_z100_ep500_12may_newest_newest.pth ---
# [60/500] [0 / 3] Loss_D: 0.0328 Loss_G: 16.1710 D(x): 0.9687 D(G(z)): 0.0000 / 0.0000 Elapsed: 0.29 secs
#  --- Discriminator model stored in DCGAN/output/ckpt_output/dcgan_dis_z100_ep500_12may_newest_newest.pth ---
#  --- Generator model stored in DCGAN/output/ckpt_output/dcgan_gen_z100_ep500_12may_newest_newest.pth ---
# [61/500] [0 / 3] Loss_D: 0.4500 Loss_G: 11.4707 D(x): 0.9995 D(G(z)): 0.2591 / 0.0001 Elapsed: 0.29 secs
#  --- Discriminator model stored in DCGAN/output/ckpt_output/dcgan_dis_z100_ep500_12may_newest_newest.pth ---
#  --- Generator model stored in DCGAN/output/ckpt_output/dcgan_gen_z100_ep500_12may_newest_newest.pth ---
# [62/500] [0 / 3] Loss_D: 0.0541 Loss_G: 7.1118 D(x): 0.9554 D(G(z)): 0.0054 / 0.0026 Elapsed: 0.19 secs
#  --- Discriminator model stored in DCGAN/output/ckpt_output/dcgan_dis_z100_ep500_12may_newest_newest.pth ---
#  --- Generator model stored in DCGAN/output/ckpt_output/dcgan_gen_z100_ep500_12may_newest_newest.pth ---
# [63/500] [0 / 3] Loss_D: 0.0285 Loss_G: 7.8663 D(x): 0.9861 D(G(z)): 0.0137 / 0.0007 Elapsed: 0.23 secs
#  --- Discriminator model stored in DCGAN/output/ckpt_output/dcgan_dis_z100_ep500_12may_newest_newest.pth ---
#  --- Generator model stored in DCGAN/output/ckpt_output/dcgan_gen_z100_ep500_12may_newest_newest.pth ---
# [64/500] [0 / 3] Loss_D: 0.0162 Loss_G: 6.2913 D(x): 0.9955 D(G(z)): 0.0115 / 0.0043 Elapsed: 0.31 secs
#  --- Discriminator model stored in DCGAN/output/ckpt_output/dcgan_dis_z100_ep500_12may_newest_newest.pth ---
#  --- Generator model stored in DCGAN/output/ckpt_output/dcgan_gen_z100_ep500_12may_newest_newest.pth ---
# [65/500] [0 / 3] Loss_D: 0.0306 Loss_G: 12.1247 D(x): 0.9709 D(G(z)): 0.0000 / 0.0000 Elapsed: 0.22 secs
#  --- Discriminator model stored in DCGAN/output/ckpt_output/dcgan_dis_z100_ep500_12may_newest_newest.pth ---
#  --- Generator model stored in DCGAN/output/ckpt_output/dcgan_gen_z100_ep500_12may_newest_newest.pth ---
# [66/500] [0 / 3] Loss_D: 0.0051 Loss_G: 6.4322 D(x): 0.9973 D(G(z)): 0.0024 / 0.0034 Elapsed: 0.20 secs
#  --- Discriminator model stored in DCGAN/output/ckpt_output/dcgan_dis_z100_ep500_12may_newest_newest.pth ---
#  --- Generator model stored in DCGAN/output/ckpt_output/dcgan_gen_z100_ep500_12may_newest_newest.pth ---
# [67/500] [0 / 3] Loss_D: 0.0056 Loss_G: 7.7166 D(x): 0.9975 D(G(z)): 0.0031 / 0.0006 Elapsed: 0.31 secs
#  --- Discriminator model stored in DCGAN/output/ckpt_output/dcgan_dis_z100_ep500_12may_newest_newest.pth ---
#  --- Generator model stored in DCGAN/output/ckpt_output/dcgan_gen_z100_ep500_12may_newest_newest.pth ---
# [68/500] [0 / 3] Loss_D: 0.0188 Loss_G: 6.0470 D(x): 0.9976 D(G(z)): 0.0162 / 0.0032 Elapsed: 0.21 secs
#  --- Discriminator model stored in DCGAN/output/ckpt_output/dcgan_dis_z100_ep500_12may_newest_newest.pth ---
#  --- Generator model stored in DCGAN/output/ckpt_output/dcgan_gen_z100_ep500_12may_newest_newest.pth ---
# [69/500] [0 / 3] Loss_D: 0.0131 Loss_G: 6.9991 D(x): 0.9913 D(G(z)): 0.0042 / 0.0014 Elapsed: 0.30 secs
#  --- Discriminator model stored in DCGAN/output/ckpt_output/dcgan_dis_z100_ep500_12may_newest_newest.pth ---
#  --- Generator model stored in DCGAN/output/ckpt_output/dcgan_gen_z100_ep500_12may_newest_newest.pth ---
# [70/500] [0 / 3] Loss_D: 0.0174 Loss_G: 6.0936 D(x): 0.9976 D(G(z)): 0.0147 / 0.0041 Elapsed: 0.23 secs
#  --- Discriminator model stored in DCGAN/output/ckpt_output/dcgan_dis_z100_ep500_12may_newest_newest.pth ---
#  --- Generator model stored in DCGAN/output/ckpt_output/dcgan_gen_z100_ep500_12may_newest_newest.pth ---
# [71/500] [0 / 3] Loss_D: 0.0250 Loss_G: 6.1065 D(x): 0.9876 D(G(z)): 0.0118 / 0.0055 Elapsed: 0.20 secs
#  --- Discriminator model stored in DCGAN/output/ckpt_output/dcgan_dis_z100_ep500_12may_newest_newest.pth ---
#  --- Generator model stored in DCGAN/output/ckpt_output/dcgan_gen_z100_ep500_12may_newest_newest.pth ---
# [72/500] [0 / 3] Loss_D: 0.0107 Loss_G: 6.4370 D(x): 0.9987 D(G(z)): 0.0094 / 0.0030 Elapsed: 0.31 secs
#  --- Discriminator model stored in DCGAN/output/ckpt_output/dcgan_dis_z100_ep500_12may_newest_newest.pth ---
#  --- Generator model stored in DCGAN/output/ckpt_output/dcgan_gen_z100_ep500_12may_newest_newest.pth ---
# [73/500] [0 / 3] Loss_D: 0.1853 Loss_G: 11.5010 D(x): 0.9999 D(G(z)): 0.1628 / 0.0001 Elapsed: 0.22 secs
#  --- Discriminator model stored in DCGAN/output/ckpt_output/dcgan_dis_z100_ep500_12may_newest_newest.pth ---
#  --- Generator model stored in DCGAN/output/ckpt_output/dcgan_gen_z100_ep500_12may_newest_newest.pth ---
# [74/500] [0 / 3] Loss_D: 0.0095 Loss_G: 7.7661 D(x): 0.9939 D(G(z)): 0.0032 / 0.0018 Elapsed: 0.20 secs
#  --- Discriminator model stored in DCGAN/output/ckpt_output/dcgan_dis_z100_ep500_12may_newest_newest.pth ---
#  --- Generator model stored in DCGAN/output/ckpt_output/dcgan_gen_z100_ep500_12may_newest_newest.pth ---
# [75/500] [0 / 3] Loss_D: 0.0413 Loss_G: 13.7043 D(x): 0.9660 D(G(z)): 0.0004 / 0.0001 Elapsed: 0.29 secs
#  --- Discriminator model stored in DCGAN/output/ckpt_output/dcgan_dis_z100_ep500_12may_newest_newest.pth ---
#  --- Generator model stored in DCGAN/output/ckpt_output/dcgan_gen_z100_ep500_12may_newest_newest.pth ---
# [76/500] [0 / 3] Loss_D: 0.0123 Loss_G: 5.6867 D(x): 0.9983 D(G(z)): 0.0105 / 0.0108 Elapsed: 0.22 secs
#  --- Discriminator model stored in DCGAN/output/ckpt_output/dcgan_dis_z100_ep500_12may_newest_newest.pth ---
#  --- Generator model stored in DCGAN/output/ckpt_output/dcgan_gen_z100_ep500_12may_newest_newest.pth ---
# [77/500] [0 / 3] Loss_D: 0.0025 Loss_G: 12.7511 D(x): 0.9975 D(G(z)): 0.0000 / 0.0000 Elapsed: 0.23 secs
#  --- Discriminator model stored in DCGAN/output/ckpt_output/dcgan_dis_z100_ep500_12may_newest_newest.pth ---
#  --- Generator model stored in DCGAN/output/ckpt_output/dcgan_gen_z100_ep500_12may_newest_newest.pth ---
# [78/500] [0 / 3] Loss_D: 0.0328 Loss_G: 6.3982 D(x): 0.9993 D(G(z)): 0.0310 / 0.0025 Elapsed: 0.23 secs
#  --- Discriminator model stored in DCGAN/output/ckpt_output/dcgan_dis_z100_ep500_12may_newest_newest.pth ---
#  --- Generator model stored in DCGAN/output/ckpt_output/dcgan_gen_z100_ep500_12may_newest_newest.pth ---
# [79/500] [0 / 3] Loss_D: 0.0064 Loss_G: 8.3937 D(x): 0.9950 D(G(z)): 0.0013 / 0.0005 Elapsed: 0.28 secs
#  --- Discriminator model stored in DCGAN/output/ckpt_output/dcgan_dis_z100_ep500_12may_newest_newest.pth ---
#  --- Generator model stored in DCGAN/output/ckpt_output/dcgan_gen_z100_ep500_12may_newest_newest.pth ---
# [80/500] [0 / 3] Loss_D: 0.0103 Loss_G: 7.5497 D(x): 0.9982 D(G(z)): 0.0084 / 0.0007 Elapsed: 0.22 secs
#  --- Discriminator model stored in DCGAN/output/ckpt_output/dcgan_dis_z100_ep500_12may_newest_newest.pth ---
#  --- Generator model stored in DCGAN/output/ckpt_output/dcgan_gen_z100_ep500_12may_newest_newest.pth ---
# [81/500] [0 / 3] Loss_D: 0.0238 Loss_G: 7.0362 D(x): 0.9983 D(G(z)): 0.0215 / 0.0012 Elapsed: 0.21 secs
#  --- Discriminator model stored in DCGAN/output/ckpt_output/dcgan_dis_z100_ep500_12may_newest_newest.pth ---
#  --- Generator model stored in DCGAN/output/ckpt_output/dcgan_gen_z100_ep500_12may_newest_newest.pth ---
# [82/500] [0 / 3] Loss_D: 0.0249 Loss_G: 6.6857 D(x): 0.9968 D(G(z)): 0.0212 / 0.0022 Elapsed: 0.21 secs
#  --- Discriminator model stored in DCGAN/output/ckpt_output/dcgan_dis_z100_ep500_12may_newest_newest.pth ---
#  --- Generator model stored in DCGAN/output/ckpt_output/dcgan_gen_z100_ep500_12may_newest_newest.pth ---
# [83/500] [0 / 3] Loss_D: 0.0787 Loss_G: 8.3505 D(x): 0.9989 D(G(z)): 0.0737 / 0.0003 Elapsed: 0.23 secs
#  --- Discriminator model stored in DCGAN/output/ckpt_output/dcgan_dis_z100_ep500_12may_newest_newest.pth ---
#  --- Generator model stored in DCGAN/output/ckpt_output/dcgan_gen_z100_ep500_12may_newest_newest.pth ---
# [84/500] [0 / 3] Loss_D: 0.0069 Loss_G: 7.4018 D(x): 0.9947 D(G(z)): 0.0015 / 0.0007 Elapsed: 0.20 secs
#  --- Discriminator model stored in DCGAN/output/ckpt_output/dcgan_dis_z100_ep500_12may_newest_newest.pth ---
#  --- Generator model stored in DCGAN/output/ckpt_output/dcgan_gen_z100_ep500_12may_newest_newest.pth ---
# [85/500] [0 / 3] Loss_D: 0.0153 Loss_G: 7.1891 D(x): 0.9951 D(G(z)): 0.0102 / 0.0012 Elapsed: 0.21 secs
#  --- Discriminator model stored in DCGAN/output/ckpt_output/dcgan_dis_z100_ep500_12may_newest_newest.pth ---
#  --- Generator model stored in DCGAN/output/ckpt_output/dcgan_gen_z100_ep500_12may_newest_newest.pth ---
# [86/500] [0 / 3] Loss_D: 0.0159 Loss_G: 6.8035 D(x): 0.9964 D(G(z)): 0.0121 / 0.0016 Elapsed: 0.32 secs
#  --- Discriminator model stored in DCGAN/output/ckpt_output/dcgan_dis_z100_ep500_12may_newest_newest.pth ---
#  --- Generator model stored in DCGAN/output/ckpt_output/dcgan_gen_z100_ep500_12may_newest_newest.pth ---
# [87/500] [0 / 3] Loss_D: 0.0178 Loss_G: 6.7650 D(x): 0.9878 D(G(z)): 0.0051 / 0.0017 Elapsed: 0.21 secs
#  --- Discriminator model stored in DCGAN/output/ckpt_output/dcgan_dis_z100_ep500_12may_newest_newest.pth ---
#  --- Generator model stored in DCGAN/output/ckpt_output/dcgan_gen_z100_ep500_12may_newest_newest.pth ---
# [88/500] [0 / 3] Loss_D: 0.0084 Loss_G: 12.7512 D(x): 0.9919 D(G(z)): 0.0003 / 0.0000 Elapsed: 0.31 secs
#  --- Discriminator model stored in DCGAN/output/ckpt_output/dcgan_dis_z100_ep500_12may_newest_newest.pth ---
#  --- Generator model stored in DCGAN/output/ckpt_output/dcgan_gen_z100_ep500_12may_newest_newest.pth ---
# [89/500] [0 / 3] Loss_D: 0.0600 Loss_G: 9.2506 D(x): 0.9986 D(G(z)): 0.0546 / 0.0001 Elapsed: 0.22 secs
#  --- Discriminator model stored in DCGAN/output/ckpt_output/dcgan_dis_z100_ep500_12may_newest_newest.pth ---
#  --- Generator model stored in DCGAN/output/ckpt_output/dcgan_gen_z100_ep500_12may_newest_newest.pth ---
# [90/500] [0 / 3] Loss_D: 0.0523 Loss_G: 9.0463 D(x): 0.9883 D(G(z)): 0.0380 / 0.0001 Elapsed: 0.22 secs
#  --- Discriminator model stored in DCGAN/output/ckpt_output/dcgan_dis_z100_ep500_12may_newest_newest.pth ---
#  --- Generator model stored in DCGAN/output/ckpt_output/dcgan_gen_z100_ep500_12may_newest_newest.pth ---
# [91/500] [0 / 3] Loss_D: 0.1433 Loss_G: 16.7956 D(x): 0.9983 D(G(z)): 0.1209 / 0.0000 Elapsed: 0.29 secs
#  --- Discriminator model stored in DCGAN/output/ckpt_output/dcgan_dis_z100_ep500_12may_newest_newest.pth ---
#  --- Generator model stored in DCGAN/output/ckpt_output/dcgan_gen_z100_ep500_12may_newest_newest.pth ---
# [92/500] [0 / 3] Loss_D: 0.0036 Loss_G: 11.4096 D(x): 0.9964 D(G(z)): 0.0000 / 0.0000 Elapsed: 0.21 secs
#  --- Discriminator model stored in DCGAN/output/ckpt_output/dcgan_dis_z100_ep500_12may_newest_newest.pth ---
#  --- Generator model stored in DCGAN/output/ckpt_output/dcgan_gen_z100_ep500_12may_newest_newest.pth ---
# [93/500] [0 / 3] Loss_D: 0.0073 Loss_G: 21.0820 D(x): 0.9929 D(G(z)): 0.0000 / 0.0000 Elapsed: 0.23 secs
#  --- Discriminator model stored in DCGAN/output/ckpt_output/dcgan_dis_z100_ep500_12may_newest_newest.pth ---
#  --- Generator model stored in DCGAN/output/ckpt_output/dcgan_gen_z100_ep500_12may_newest_newest.pth ---
# [94/500] [0 / 3] Loss_D: 0.0035 Loss_G: 10.6802 D(x): 0.9966 D(G(z)): 0.0000 / 0.0001 Elapsed: 0.21 secs
#  --- Discriminator model stored in DCGAN/output/ckpt_output/dcgan_dis_z100_ep500_12may_newest_newest.pth ---
#  --- Generator model stored in DCGAN/output/ckpt_output/dcgan_gen_z100_ep500_12may_newest_newest.pth ---
# [95/500] [0 / 3] Loss_D: 0.0203 Loss_G: 17.7288 D(x): 0.9815 D(G(z)): 0.0000 / 0.0000 Elapsed: 0.29 secs
#  --- Discriminator model stored in DCGAN/output/ckpt_output/dcgan_dis_z100_ep500_12may_newest_newest.pth ---
#  --- Generator model stored in DCGAN/output/ckpt_output/dcgan_gen_z100_ep500_12may_newest_newest.pth ---
# [96/500] [0 / 3] Loss_D: 0.0036 Loss_G: 10.2980 D(x): 0.9966 D(G(z)): 0.0003 / 0.0002 Elapsed: 0.22 secs
#  --- Discriminator model stored in DCGAN/output/ckpt_output/dcgan_dis_z100_ep500_12may_newest_newest.pth ---
#  --- Generator model stored in DCGAN/output/ckpt_output/dcgan_gen_z100_ep500_12may_newest_newest.pth ---
# [97/500] [0 / 3] Loss_D: 0.0728 Loss_G: 9.4821 D(x): 0.9503 D(G(z)): 0.0012 / 0.0002 Elapsed: 0.28 secs
#  --- Discriminator model stored in DCGAN/output/ckpt_output/dcgan_dis_z100_ep500_12may_newest_newest.pth ---
#  --- Generator model stored in DCGAN/output/ckpt_output/dcgan_gen_z100_ep500_12may_newest_newest.pth ---
# [98/500] [0 / 3] Loss_D: 0.0752 Loss_G: 9.5310 D(x): 0.9964 D(G(z)): 0.0658 / 0.0001 Elapsed: 0.19 secs
#  --- Discriminator model stored in DCGAN/output/ckpt_output/dcgan_dis_z100_ep500_12may_newest_newest.pth ---
#  --- Generator model stored in DCGAN/output/ckpt_output/dcgan_gen_z100_ep500_12may_newest_newest.pth ---
# [99/500] [0 / 3] Loss_D: 0.0291 Loss_G: 6.3637 D(x): 0.9854 D(G(z)): 0.0138 / 0.0033 Elapsed: 0.29 secs
#  --- Discriminator model stored in DCGAN/output/ckpt_output/dcgan_dis_z100_ep500_12may_newest_newest.pth ---
#  --- Generator model stored in DCGAN/output/ckpt_output/dcgan_gen_z100_ep500_12may_newest_newest.pth ---
# [100/500] [0 / 3] Loss_D: 0.0229 Loss_G: 6.7916 D(x): 0.9929 D(G(z)): 0.0155 / 0.0017 Elapsed: 0.31 secs
#  --- Discriminator model stored in DCGAN/output/ckpt_output/dcgan_dis_z100_ep500_12may_newest_newest.pth ---
#  --- Generator model stored in DCGAN/output/ckpt_output/dcgan_gen_z100_ep500_12may_newest_newest.pth ---
# [101/500] [0 / 3] Loss_D: 0.0172 Loss_G: 8.7100 D(x): 0.9857 D(G(z)): 0.0013 / 0.0002 Elapsed: 0.22 secs
#  --- Discriminator model stored in DCGAN/output/ckpt_output/dcgan_dis_z100_ep500_12may_newest_newest.pth ---
#  --- Generator model stored in DCGAN/output/ckpt_output/dcgan_gen_z100_ep500_12may_newest_newest.pth ---
# [102/500] [0 / 3] Loss_D: 0.0249 Loss_G: 7.4897 D(x): 0.9948 D(G(z)): 0.0192 / 0.0007 Elapsed: 0.29 secs
#  --- Discriminator model stored in DCGAN/output/ckpt_output/dcgan_dis_z100_ep500_12may_newest_newest.pth ---
#  --- Generator model stored in DCGAN/output/ckpt_output/dcgan_gen_z100_ep500_12may_newest_newest.pth ---
# [103/500] [0 / 3] Loss_D: 0.0080 Loss_G: 6.9552 D(x): 0.9983 D(G(z)): 0.0062 / 0.0020 Elapsed: 0.29 secs
#  --- Discriminator model stored in DCGAN/output/ckpt_output/dcgan_dis_z100_ep500_12may_newest_newest.pth ---
#  --- Generator model stored in DCGAN/output/ckpt_output/dcgan_gen_z100_ep500_12may_newest_newest.pth ---
# [104/500] [0 / 3] Loss_D: 0.0089 Loss_G: 7.0205 D(x): 0.9975 D(G(z)): 0.0064 / 0.0012 Elapsed: 0.27 secs
#  --- Discriminator model stored in DCGAN/output/ckpt_output/dcgan_dis_z100_ep500_12may_newest_newest.pth ---
#  --- Generator model stored in DCGAN/output/ckpt_output/dcgan_gen_z100_ep500_12may_newest_newest.pth ---
# [105/500] [0 / 3] Loss_D: 0.0123 Loss_G: 6.5152 D(x): 0.9978 D(G(z)): 0.0099 / 0.0021 Elapsed: 0.29 secs
#  --- Discriminator model stored in DCGAN/output/ckpt_output/dcgan_dis_z100_ep500_12may_newest_newest.pth ---
#  --- Generator model stored in DCGAN/output/ckpt_output/dcgan_gen_z100_ep500_12may_newest_newest.pth ---
# [106/500] [0 / 3] Loss_D: 0.0406 Loss_G: 7.5849 D(x): 0.9980 D(G(z)): 0.0375 / 0.0006 Elapsed: 0.23 secs
#  --- Discriminator model stored in DCGAN/output/ckpt_output/dcgan_dis_z100_ep500_12may_newest_newest.pth ---
#  --- Generator model stored in DCGAN/output/ckpt_output/dcgan_gen_z100_ep500_12may_newest_newest.pth ---
# [107/500] [0 / 3] Loss_D: 0.0053 Loss_G: 6.5593 D(x): 0.9981 D(G(z)): 0.0034 / 0.0018 Elapsed: 0.23 secs
#  --- Discriminator model stored in DCGAN/output/ckpt_output/dcgan_dis_z100_ep500_12may_newest_newest.pth ---
#  --- Generator model stored in DCGAN/output/ckpt_output/dcgan_gen_z100_ep500_12may_newest_newest.pth ---
# [108/500] [0 / 3] Loss_D: 0.0068 Loss_G: 7.4043 D(x): 0.9961 D(G(z)): 0.0028 / 0.0008 Elapsed: 0.23 secs
#  --- Discriminator model stored in DCGAN/output/ckpt_output/dcgan_dis_z100_ep500_12may_newest_newest.pth ---
#  --- Generator model stored in DCGAN/output/ckpt_output/dcgan_gen_z100_ep500_12may_newest_newest.pth ---
# [109/500] [0 / 3] Loss_D: 0.0105 Loss_G: 6.5404 D(x): 0.9975 D(G(z)): 0.0080 / 0.0017 Elapsed: 0.21 secs
#  --- Discriminator model stored in DCGAN/output/ckpt_output/dcgan_dis_z100_ep500_12may_newest_newest.pth ---
#  --- Generator model stored in DCGAN/output/ckpt_output/dcgan_gen_z100_ep500_12may_newest_newest.pth ---
# [110/500] [0 / 3] Loss_D: 0.0111 Loss_G: 7.1203 D(x): 0.9928 D(G(z)): 0.0037 / 0.0010 Elapsed: 0.30 secs
#  --- Discriminator model stored in DCGAN/output/ckpt_output/dcgan_dis_z100_ep500_12may_newest_newest.pth ---
#  --- Generator model stored in DCGAN/output/ckpt_output/dcgan_gen_z100_ep500_12may_newest_newest.pth ---
# [111/500] [0 / 3] Loss_D: 0.0119 Loss_G: 6.2559 D(x): 0.9944 D(G(z)): 0.0062 / 0.0024 Elapsed: 0.21 secs
#  --- Discriminator model stored in DCGAN/output/ckpt_output/dcgan_dis_z100_ep500_12may_newest_newest.pth ---
#  --- Generator model stored in DCGAN/output/ckpt_output/dcgan_gen_z100_ep500_12may_newest_newest.pth ---
# [112/500] [0 / 3] Loss_D: 0.0173 Loss_G: 6.7601 D(x): 0.9930 D(G(z)): 0.0100 / 0.0016 Elapsed: 0.22 secs
#  --- Discriminator model stored in DCGAN/output/ckpt_output/dcgan_dis_z100_ep500_12may_newest_newest.pth ---
#  --- Generator model stored in DCGAN/output/ckpt_output/dcgan_gen_z100_ep500_12may_newest_newest.pth ---
# [113/500] [0 / 3] Loss_D: 0.0809 Loss_G: 11.1470 D(x): 0.9972 D(G(z)): 0.0718 / 0.0000 Elapsed: 0.29 secs
#  --- Discriminator model stored in DCGAN/output/ckpt_output/dcgan_dis_z100_ep500_12may_newest_newest.pth ---
#  --- Generator model stored in DCGAN/output/ckpt_output/dcgan_gen_z100_ep500_12may_newest_newest.pth ---
# [114/500] [0 / 3] Loss_D: 0.0022 Loss_G: 7.3379 D(x): 0.9987 D(G(z)): 0.0010 / 0.0009 Elapsed: 0.31 secs
#  --- Discriminator model stored in DCGAN/output/ckpt_output/dcgan_dis_z100_ep500_12may_newest_newest.pth ---
#  --- Generator model stored in DCGAN/output/ckpt_output/dcgan_gen_z100_ep500_12may_newest_newest.pth ---
# [115/500] [0 / 3] Loss_D: 0.0043 Loss_G: 11.0520 D(x): 0.9965 D(G(z)): 0.0007 / 0.0000 Elapsed: 0.29 secs
#  --- Discriminator model stored in DCGAN/output/ckpt_output/dcgan_dis_z100_ep500_12may_newest_newest.pth ---
#  --- Generator model stored in DCGAN/output/ckpt_output/dcgan_gen_z100_ep500_12may_newest_newest.pth ---
# [116/500] [0 / 3] Loss_D: 0.0070 Loss_G: 6.5794 D(x): 0.9966 D(G(z)): 0.0036 / 0.0021 Elapsed: 0.22 secs
#  --- Discriminator model stored in DCGAN/output/ckpt_output/dcgan_dis_z100_ep500_12may_newest_newest.pth ---
#  --- Generator model stored in DCGAN/output/ckpt_output/dcgan_gen_z100_ep500_12may_newest_newest.pth ---
# [117/500] [0 / 3] Loss_D: 0.0063 Loss_G: 8.0432 D(x): 0.9963 D(G(z)): 0.0025 / 0.0004 Elapsed: 0.27 secs
#  --- Discriminator model stored in DCGAN/output/ckpt_output/dcgan_dis_z100_ep500_12may_newest_newest.pth ---
#  --- Generator model stored in DCGAN/output/ckpt_output/dcgan_gen_z100_ep500_12may_newest_newest.pth ---
# [118/500] [0 / 3] Loss_D: 0.0100 Loss_G: 6.9831 D(x): 0.9947 D(G(z)): 0.0046 / 0.0013 Elapsed: 0.23 secs
#  --- Discriminator model stored in DCGAN/output/ckpt_output/dcgan_dis_z100_ep500_12may_newest_newest.pth ---
#  --- Generator model stored in DCGAN/output/ckpt_output/dcgan_gen_z100_ep500_12may_newest_newest.pth ---
# [119/500] [0 / 3] Loss_D: 0.0232 Loss_G: 6.4901 D(x): 0.9870 D(G(z)): 0.0097 / 0.0017 Elapsed: 0.23 secs
#  --- Discriminator model stored in DCGAN/output/ckpt_output/dcgan_dis_z100_ep500_12may_newest_newest.pth ---
#  --- Generator model stored in DCGAN/output/ckpt_output/dcgan_gen_z100_ep500_12may_newest_newest.pth ---
# [120/500] [0 / 3] Loss_D: 0.0064 Loss_G: 8.2445 D(x): 0.9950 D(G(z)): 0.0013 / 0.0004 Elapsed: 0.22 secs
#  --- Discriminator model stored in DCGAN/output/ckpt_output/dcgan_dis_z100_ep500_12may_newest_newest.pth ---
#  --- Generator model stored in DCGAN/output/ckpt_output/dcgan_gen_z100_ep500_12may_newest_newest.pth ---
# [121/500] [0 / 3] Loss_D: 0.0084 Loss_G: 7.9995 D(x): 0.9944 D(G(z)): 0.0028 / 0.0004 Elapsed: 0.28 secs
#  --- Discriminator model stored in DCGAN/output/ckpt_output/dcgan_dis_z100_ep500_12may_newest_newest.pth ---
#  --- Generator model stored in DCGAN/output/ckpt_output/dcgan_gen_z100_ep500_12may_newest_newest.pth ---
# [122/500] [0 / 3] Loss_D: 0.0279 Loss_G: 8.9773 D(x): 0.9986 D(G(z)): 0.0257 / 0.0002 Elapsed: 0.30 secs
#  --- Discriminator model stored in DCGAN/output/ckpt_output/dcgan_dis_z100_ep500_12may_newest_newest.pth ---
#  --- Generator model stored in DCGAN/output/ckpt_output/dcgan_gen_z100_ep500_12may_newest_newest.pth ---
# [123/500] [0 / 3] Loss_D: 0.7981 Loss_G: 38.4722 D(x): 0.9994 D(G(z)): 0.5084 / 0.0000 Elapsed: 0.23 secs
#  --- Discriminator model stored in DCGAN/output/ckpt_output/dcgan_dis_z100_ep500_12may_newest_newest.pth ---
#  --- Generator model stored in DCGAN/output/ckpt_output/dcgan_gen_z100_ep500_12may_newest_newest.pth ---
# [124/500] [0 / 3] Loss_D: 0.0284 Loss_G: 33.4907 D(x): 0.9770 D(G(z)): 0.0000 / 0.0000 Elapsed: 0.28 secs
#  --- Discriminator model stored in DCGAN/output/ckpt_output/dcgan_dis_z100_ep500_12may_newest_newest.pth ---
#  --- Generator model stored in DCGAN/output/ckpt_output/dcgan_gen_z100_ep500_12may_newest_newest.pth ---
# [125/500] [0 / 3] Loss_D: 0.0000 Loss_G: 30.2763 D(x): 1.0000 D(G(z)): 0.0000 / 0.0000 Elapsed: 0.30 secs
#  --- Discriminator model stored in DCGAN/output/ckpt_output/dcgan_dis_z100_ep500_12may_newest_newest.pth ---
#  --- Generator model stored in DCGAN/output/ckpt_output/dcgan_gen_z100_ep500_12may_newest_newest.pth ---
# [126/500] [0 / 3] Loss_D: 0.0007 Loss_G: 15.9828 D(x): 1.0000 D(G(z)): 0.0007 / 0.0007 Elapsed: 0.22 secs
#  --- Discriminator model stored in DCGAN/output/ckpt_output/dcgan_dis_z100_ep500_12may_newest_newest.pth ---
#  --- Generator model stored in DCGAN/output/ckpt_output/dcgan_gen_z100_ep500_12may_newest_newest.pth ---
# [127/500] [0 / 3] Loss_D: 0.1372 Loss_G: 35.0552 D(x): 0.9444 D(G(z)): 0.0000 / 0.0000 Elapsed: 0.29 secs
#  --- Discriminator model stored in DCGAN/output/ckpt_output/dcgan_dis_z100_ep500_12may_newest_newest.pth ---
#  --- Generator model stored in DCGAN/output/ckpt_output/dcgan_gen_z100_ep500_12may_newest_newest.pth ---
# [128/500] [0 / 3] Loss_D: 0.0994 Loss_G: 35.6948 D(x): 0.9491 D(G(z)): 0.0000 / 0.0000 Elapsed: 0.22 secs
#  --- Discriminator model stored in DCGAN/output/ckpt_output/dcgan_dis_z100_ep500_12may_newest_newest.pth ---
#  --- Generator model stored in DCGAN/output/ckpt_output/dcgan_gen_z100_ep500_12may_newest_newest.pth ---
# [129/500] [0 / 3] Loss_D: 0.0002 Loss_G: 35.0945 D(x): 0.9998 D(G(z)): 0.0000 / 0.0000 Elapsed: 0.29 secs
#  --- Discriminator model stored in DCGAN/output/ckpt_output/dcgan_dis_z100_ep500_12may_newest_newest.pth ---
#  --- Generator model stored in DCGAN/output/ckpt_output/dcgan_gen_z100_ep500_12may_newest_newest.pth ---
# [130/500] [0 / 3] Loss_D: 0.0001 Loss_G: 32.7716 D(x): 0.9999 D(G(z)): 0.0000 / 0.0000 Elapsed: 0.23 secs
#  --- Discriminator model stored in DCGAN/output/ckpt_output/dcgan_dis_z100_ep500_12may_newest_newest.pth ---
#  --- Generator model stored in DCGAN/output/ckpt_output/dcgan_gen_z100_ep500_12may_newest_newest.pth ---
# [131/500] [0 / 3] Loss_D: 0.0001 Loss_G: 30.4316 D(x): 0.9999 D(G(z)): 0.0000 / 0.0000 Elapsed: 0.22 secs
#  --- Discriminator model stored in DCGAN/output/ckpt_output/dcgan_dis_z100_ep500_12may_newest_newest.pth ---
#  --- Generator model stored in DCGAN/output/ckpt_output/dcgan_gen_z100_ep500_12may_newest_newest.pth ---
# [132/500] [0 / 3] Loss_D: 0.0000 Loss_G: 24.6398 D(x): 1.0000 D(G(z)): 0.0000 / 0.0000 Elapsed: 0.28 secs
#  --- Discriminator model stored in DCGAN/output/ckpt_output/dcgan_dis_z100_ep500_12may_newest_newest.pth ---
#  --- Generator model stored in DCGAN/output/ckpt_output/dcgan_gen_z100_ep500_12may_newest_newest.pth ---
# [133/500] [0 / 3] Loss_D: 0.0002 Loss_G: 14.0474 D(x): 1.0000 D(G(z)): 0.0002 / 0.0002 Elapsed: 0.21 secs
#  --- Discriminator model stored in DCGAN/output/ckpt_output/dcgan_dis_z100_ep500_12may_newest_newest.pth ---
#  --- Generator model stored in DCGAN/output/ckpt_output/dcgan_gen_z100_ep500_12may_newest_newest.pth ---
# [134/500] [0 / 3] Loss_D: 0.0011 Loss_G: 30.8191 D(x): 0.9989 D(G(z)): 0.0000 / 0.0000 Elapsed: 0.30 secs
#  --- Discriminator model stored in DCGAN/output/ckpt_output/dcgan_dis_z100_ep500_12may_newest_newest.pth ---
#  --- Generator model stored in DCGAN/output/ckpt_output/dcgan_gen_z100_ep500_12may_newest_newest.pth ---
# [135/500] [0 / 3] Loss_D: 0.0005 Loss_G: 29.5400 D(x): 0.9995 D(G(z)): 0.0000 / 0.0000 Elapsed: 0.20 secs
#  --- Discriminator model stored in DCGAN/output/ckpt_output/dcgan_dis_z100_ep500_12may_newest_newest.pth ---
#  --- Generator model stored in DCGAN/output/ckpt_output/dcgan_gen_z100_ep500_12may_newest_newest.pth ---
# [136/500] [0 / 3] Loss_D: 0.0009 Loss_G: 22.5387 D(x): 0.9991 D(G(z)): 0.0000 / 0.0000 Elapsed: 0.23 secs
#  --- Discriminator model stored in DCGAN/output/ckpt_output/dcgan_dis_z100_ep500_12may_newest_newest.pth ---
#  --- Generator model stored in DCGAN/output/ckpt_output/dcgan_gen_z100_ep500_12may_newest_newest.pth ---
# [137/500] [0 / 3] Loss_D: 0.0007 Loss_G: 14.1334 D(x): 0.9998 D(G(z)): 0.0005 / 0.0005 Elapsed: 0.23 secs
#  --- Discriminator model stored in DCGAN/output/ckpt_output/dcgan_dis_z100_ep500_12may_newest_newest.pth ---
#  --- Generator model stored in DCGAN/output/ckpt_output/dcgan_gen_z100_ep500_12may_newest_newest.pth ---
# [138/500] [0 / 3] Loss_D: 0.0033 Loss_G: 13.4344 D(x): 0.9976 D(G(z)): 0.0009 / 0.0000 Elapsed: 0.28 secs
#  --- Discriminator model stored in DCGAN/output/ckpt_output/dcgan_dis_z100_ep500_12may_newest_newest.pth ---
#  --- Generator model stored in DCGAN/output/ckpt_output/dcgan_gen_z100_ep500_12may_newest_newest.pth ---
# [139/500] [0 / 3] Loss_D: 0.0256 Loss_G: 6.8414 D(x): 0.9975 D(G(z)): 0.0224 / 0.0026 Elapsed: 0.30 secs
#  --- Discriminator model stored in DCGAN/output/ckpt_output/dcgan_dis_z100_ep500_12may_newest_newest.pth ---
#  --- Generator model stored in DCGAN/output/ckpt_output/dcgan_gen_z100_ep500_12may_newest_newest.pth ---
# [140/500] [0 / 3] Loss_D: 0.1065 Loss_G: 26.8350 D(x): 0.9175 D(G(z)): 0.0000 / 0.0000 Elapsed: 0.23 secs
#  --- Discriminator model stored in DCGAN/output/ckpt_output/dcgan_dis_z100_ep500_12may_newest_newest.pth ---
#  --- Generator model stored in DCGAN/output/ckpt_output/dcgan_gen_z100_ep500_12may_newest_newest.pth ---
# [141/500] [0 / 3] Loss_D: 0.0041 Loss_G: 19.7645 D(x): 0.9960 D(G(z)): 0.0000 / 0.0000 Elapsed: 0.22 secs
#  --- Discriminator model stored in DCGAN/output/ckpt_output/dcgan_dis_z100_ep500_12may_newest_newest.pth ---
#  --- Generator model stored in DCGAN/output/ckpt_output/dcgan_gen_z100_ep500_12may_newest_newest.pth ---
# [142/500] [0 / 3] Loss_D: 0.0028 Loss_G: 12.0556 D(x): 0.9990 D(G(z)): 0.0018 / 0.0016 Elapsed: 0.24 secs
#  --- Discriminator model stored in DCGAN/output/ckpt_output/dcgan_dis_z100_ep500_12may_newest_newest.pth ---
#  --- Generator model stored in DCGAN/output/ckpt_output/dcgan_gen_z100_ep500_12may_newest_newest.pth ---
# [143/500] [0 / 3] Loss_D: 0.0398 Loss_G: 7.7877 D(x): 0.9993 D(G(z)): 0.0376 / 0.0008 Elapsed: 0.21 secs
#  --- Discriminator model stored in DCGAN/output/ckpt_output/dcgan_dis_z100_ep500_12may_newest_newest.pth ---
#  --- Generator model stored in DCGAN/output/ckpt_output/dcgan_gen_z100_ep500_12may_newest_newest.pth ---
# [144/500] [0 / 3] Loss_D: 0.0116 Loss_G: 11.5491 D(x): 0.9890 D(G(z)): 0.0001 / 0.0000 Elapsed: 0.30 secs
#  --- Discriminator model stored in DCGAN/output/ckpt_output/dcgan_dis_z100_ep500_12may_newest_newest.pth ---
#  --- Generator model stored in DCGAN/output/ckpt_output/dcgan_gen_z100_ep500_12may_newest_newest.pth ---
# [145/500] [0 / 3] Loss_D: 0.8304 Loss_G: 23.2307 D(x): 0.9991 D(G(z)): 0.4398 / 0.0000 Elapsed: 0.21 secs
#  --- Discriminator model stored in DCGAN/output/ckpt_output/dcgan_dis_z100_ep500_12may_newest_newest.pth ---
#  --- Generator model stored in DCGAN/output/ckpt_output/dcgan_gen_z100_ep500_12may_newest_newest.pth ---
# [146/500] [0 / 3] Loss_D: 0.0042 Loss_G: 23.7460 D(x): 0.9958 D(G(z)): 0.0000 / 0.0000 Elapsed: 0.22 secs
#  --- Discriminator model stored in DCGAN/output/ckpt_output/dcgan_dis_z100_ep500_12may_newest_newest.pth ---
#  --- Generator model stored in DCGAN/output/ckpt_output/dcgan_gen_z100_ep500_12may_newest_newest.pth ---
# [147/500] [0 / 3] Loss_D: 0.0022 Loss_G: 12.0640 D(x): 0.9993 D(G(z)): 0.0014 / 0.0014 Elapsed: 0.30 secs
#  --- Discriminator model stored in DCGAN/output/ckpt_output/dcgan_dis_z100_ep500_12may_newest_newest.pth ---
#  --- Generator model stored in DCGAN/output/ckpt_output/dcgan_gen_z100_ep500_12may_newest_newest.pth ---
# [148/500] [0 / 3] Loss_D: 0.0790 Loss_G: 7.5578 D(x): 0.9992 D(G(z)): 0.0738 / 0.0013 Elapsed: 0.29 secs
#  --- Discriminator model stored in DCGAN/output/ckpt_output/dcgan_dis_z100_ep500_12may_newest_newest.pth ---
#  --- Generator model stored in DCGAN/output/ckpt_output/dcgan_gen_z100_ep500_12may_newest_newest.pth ---
# [149/500] [0 / 3] Loss_D: 0.0918 Loss_G: 9.1291 D(x): 0.9942 D(G(z)): 0.0752 / 0.0002 Elapsed: 0.30 secs
#  --- Discriminator model stored in DCGAN/output/ckpt_output/dcgan_dis_z100_ep500_12may_newest_newest.pth ---
#  --- Generator model stored in DCGAN/output/ckpt_output/dcgan_gen_z100_ep500_12may_newest_newest.pth ---
# [150/500] [0 / 3] Loss_D: 0.0184 Loss_G: 6.4086 D(x): 0.9962 D(G(z)): 0.0142 / 0.0028 Elapsed: 0.30 secs
#  --- Discriminator model stored in DCGAN/output/ckpt_output/dcgan_dis_z100_ep500_12may_newest_newest.pth ---
#  --- Generator model stored in DCGAN/output/ckpt_output/dcgan_gen_z100_ep500_12may_newest_newest.pth ---
# [151/500] [0 / 3] Loss_D: 0.0316 Loss_G: 7.4703 D(x): 0.9835 D(G(z)): 0.0145 / 0.0009 Elapsed: 0.21 secs
# ...
# [451/500] [0 / 3] Loss_D: 0.0000 Loss_G: 42.8827 D(x): 1.0000 D(G(z)): 0.0000 / 0.0000 Elapsed: 0.28 secs
#  --- Discriminator model stored in DCGAN/output/ckpt_output/dcgan_dis_z100_ep500_12may_newest_newest.pth ---
#  --- Generator model stored in DCGAN/output/ckpt_output/dcgan_gen_z100_ep500_12may_newest_newest.pth ---
# [452/500] [0 / 3] Loss_D: 0.0000 Loss_G: 41.0922 D(x): 1.0000 D(G(z)): 0.0000 / 0.0000 Elapsed: 0.22 secs
#  --- Discriminator model stored in DCGAN/output/ckpt_output/dcgan_dis_z100_ep500_12may_newest_newest.pth ---
#  --- Generator model stored in DCGAN/output/ckpt_output/dcgan_gen_z100_ep500_12may_newest_newest.pth ---
# [453/500] [0 / 3] Loss_D: 0.0001 Loss_G: 39.9432 D(x): 0.9999 D(G(z)): 0.0000 / 0.0000 Elapsed: 0.22 secs
#  --- Discriminator model stored in DCGAN/output/ckpt_output/dcgan_dis_z100_ep500_12may_newest_newest.pth ---
#  --- Generator model stored in DCGAN/output/ckpt_output/dcgan_gen_z100_ep500_12may_newest_newest.pth ---
# [454/500] [0 / 3] Loss_D: 0.0001 Loss_G: 36.7786 D(x): 0.9999 D(G(z)): 0.0000 / 0.0000 Elapsed: 0.21 secs
#  --- Discriminator model stored in DCGAN/output/ckpt_output/dcgan_dis_z100_ep500_12may_newest_newest.pth ---
#  --- Generator model stored in DCGAN/output/ckpt_output/dcgan_gen_z100_ep500_12may_newest_newest.pth ---
# [455/500] [0 / 3] Loss_D: 0.0001 Loss_G: 27.1715 D(x): 1.0000 D(G(z)): 0.0001 / 0.0001 Elapsed: 0.23 secs
#  --- Discriminator model stored in DCGAN/output/ckpt_output/dcgan_dis_z100_ep500_12may_newest_newest.pth ---
#  --- Generator model stored in DCGAN/output/ckpt_output/dcgan_gen_z100_ep500_12may_newest_newest.pth ---
# [456/500] [0 / 3] Loss_D: 0.3708 Loss_G: 19.7735 D(x): 0.9999 D(G(z)): 0.2184 / 0.0000 Elapsed: 0.23 secs
#  --- Discriminator model stored in DCGAN/output/ckpt_output/dcgan_dis_z100_ep500_12may_newest_newest.pth ---
#  --- Generator model stored in DCGAN/output/ckpt_output/dcgan_gen_z100_ep500_12may_newest_newest.pth ---
# [457/500] [0 / 3] Loss_D: 0.0034 Loss_G: 13.0068 D(x): 0.9967 D(G(z)): 0.0000 / 0.0000 Elapsed: 0.29 secs
#  --- Discriminator model stored in DCGAN/output/ckpt_output/dcgan_dis_z100_ep500_12may_newest_newest.pth ---
#  --- Generator model stored in DCGAN/output/ckpt_output/dcgan_gen_z100_ep500_12may_newest_newest.pth ---
# [458/500] [0 / 3] Loss_D: 0.0030 Loss_G: 17.5190 D(x): 0.9971 D(G(z)): 0.0000 / 0.0000 Elapsed: 0.21 secs
#  --- Discriminator model stored in DCGAN/output/ckpt_output/dcgan_dis_z100_ep500_12may_newest_newest.pth ---
#  --- Generator model stored in DCGAN/output/ckpt_output/dcgan_gen_z100_ep500_12may_newest_newest.pth ---
# [459/500] [0 / 3] Loss_D: 0.0043 Loss_G: 6.9612 D(x): 0.9994 D(G(z)): 0.0036 / 0.0037 Elapsed: 0.20 secs
#  --- Discriminator model stored in DCGAN/output/ckpt_output/dcgan_dis_z100_ep500_12may_newest_newest.pth ---
#  --- Generator model stored in DCGAN/output/ckpt_output/dcgan_gen_z100_ep500_12may_newest_newest.pth ---
# [460/500] [0 / 3] Loss_D: 0.0036 Loss_G: 10.1148 D(x): 0.9975 D(G(z)): 0.0012 / 0.0003 Elapsed: 0.30 secs
#  --- Discriminator model stored in DCGAN/output/ckpt_output/dcgan_dis_z100_ep500_12may_newest_newest.pth ---
#  --- Generator model stored in DCGAN/output/ckpt_output/dcgan_gen_z100_ep500_12may_newest_newest.pth ---
# [461/500] [0 / 3] Loss_D: 0.0198 Loss_G: 7.0232 D(x): 0.9929 D(G(z)): 0.0124 / 0.0015 Elapsed: 0.23 secs
#  --- Discriminator model stored in DCGAN/output/ckpt_output/dcgan_dis_z100_ep500_12may_newest_newest.pth ---
#  --- Generator model stored in DCGAN/output/ckpt_output/dcgan_gen_z100_ep500_12may_newest_newest.pth ---
# [462/500] [0 / 3] Loss_D: 0.0590 Loss_G: 8.4925 D(x): 0.9966 D(G(z)): 0.0528 / 0.0004 Elapsed: 0.29 secs
#  --- Discriminator model stored in DCGAN/output/ckpt_output/dcgan_dis_z100_ep500_12may_newest_newest.pth ---
#  --- Generator model stored in DCGAN/output/ckpt_output/dcgan_gen_z100_ep500_12may_newest_newest.pth ---
# [463/500] [0 / 3] Loss_D: 0.2101 Loss_G: 16.4605 D(x): 0.9972 D(G(z)): 0.1700 / 0.0000 Elapsed: 0.27 secs
#  --- Discriminator model stored in DCGAN/output/ckpt_output/dcgan_dis_z100_ep500_12may_newest_newest.pth ---
#  --- Generator model stored in DCGAN/output/ckpt_output/dcgan_gen_z100_ep500_12may_newest_newest.pth ---
# [464/500] [0 / 3] Loss_D: 0.0490 Loss_G: 14.2074 D(x): 0.9607 D(G(z)): 0.0002 / 0.0002 Elapsed: 0.21 secs
#  --- Discriminator model stored in DCGAN/output/ckpt_output/dcgan_dis_z100_ep500_12may_newest_newest.pth ---
#  --- Generator model stored in DCGAN/output/ckpt_output/dcgan_gen_z100_ep500_12may_newest_newest.pth ---
# [465/500] [0 / 3] Loss_D: 0.0491 Loss_G: 8.3832 D(x): 0.9995 D(G(z)): 0.0464 / 0.0004 Elapsed: 0.28 secs
#  --- Discriminator model stored in DCGAN/output/ckpt_output/dcgan_dis_z100_ep500_12may_newest_newest.pth ---
#  --- Generator model stored in DCGAN/output/ckpt_output/dcgan_gen_z100_ep500_12may_newest_newest.pth ---
# [466/500] [0 / 3] Loss_D: 0.0206 Loss_G: 6.7708 D(x): 0.9940 D(G(z)): 0.0144 / 0.0018 Elapsed: 0.28 secs
#  --- Discriminator model stored in DCGAN/output/ckpt_output/dcgan_dis_z100_ep500_12may_newest_newest.pth ---
#  --- Generator model stored in DCGAN/output/ckpt_output/dcgan_gen_z100_ep500_12may_newest_newest.pth ---
# [467/500] [0 / 3] Loss_D: 0.0257 Loss_G: 6.4780 D(x): 0.9985 D(G(z)): 0.0237 / 0.0017 Elapsed: 0.30 secs
#  --- Discriminator model stored in DCGAN/output/ckpt_output/dcgan_dis_z100_ep500_12may_newest_newest.pth ---
#  --- Generator model stored in DCGAN/output/ckpt_output/dcgan_gen_z100_ep500_12may_newest_newest.pth ---
# [468/500] [0 / 3] Loss_D: 0.0116 Loss_G: 6.8148 D(x): 0.9948 D(G(z)): 0.0062 / 0.0018 Elapsed: 0.21 secs
#  --- Discriminator model stored in DCGAN/output/ckpt_output/dcgan_dis_z100_ep500_12may_newest_newest.pth ---
#  --- Generator model stored in DCGAN/output/ckpt_output/dcgan_gen_z100_ep500_12may_newest_newest.pth ---
# [469/500] [0 / 3] Loss_D: 0.0604 Loss_G: 8.2090 D(x): 0.9983 D(G(z)): 0.0551 / 0.0004 Elapsed: 0.29 secs
#  --- Discriminator model stored in DCGAN/output/ckpt_output/dcgan_dis_z100_ep500_12may_newest_newest.pth ---
#  --- Generator model stored in DCGAN/output/ckpt_output/dcgan_gen_z100_ep500_12may_newest_newest.pth ---
# [470/500] [0 / 3] Loss_D: 0.0227 Loss_G: 7.5215 D(x): 0.9796 D(G(z)): 0.0012 / 0.0009 Elapsed: 0.22 secs
#  --- Discriminator model stored in DCGAN/output/ckpt_output/dcgan_dis_z100_ep500_12may_newest_newest.pth ---
#  --- Generator model stored in DCGAN/output/ckpt_output/dcgan_gen_z100_ep500_12may_newest_newest.pth ---
# [471/500] [0 / 3] Loss_D: 0.0192 Loss_G: 7.5492 D(x): 0.9934 D(G(z)): 0.0124 / 0.0008 Elapsed: 0.21 secs
#  --- Discriminator model stored in DCGAN/output/ckpt_output/dcgan_dis_z100_ep500_12may_newest_newest.pth ---
#  --- Generator model stored in DCGAN/output/ckpt_output/dcgan_gen_z100_ep500_12may_newest_newest.pth ---
# [472/500] [0 / 3] Loss_D: 0.0278 Loss_G: 6.0350 D(x): 0.9830 D(G(z)): 0.0096 / 0.0034 Elapsed: 0.24 secs
#  --- Discriminator model stored in DCGAN/output/ckpt_output/dcgan_dis_z100_ep500_12may_newest_newest.pth ---
#  --- Generator model stored in DCGAN/output/ckpt_output/dcgan_gen_z100_ep500_12may_newest_newest.pth ---
# [473/500] [0 / 3] Loss_D: 0.0076 Loss_G: 9.6552 D(x): 0.9944 D(G(z)): 0.0020 / 0.0008 Elapsed: 0.29 secs
#  --- Discriminator model stored in DCGAN/output/ckpt_output/dcgan_dis_z100_ep500_12may_newest_newest.pth ---
#  --- Generator model stored in DCGAN/output/ckpt_output/dcgan_gen_z100_ep500_12may_newest_newest.pth ---
# [474/500] [0 / 3] Loss_D: 0.0083 Loss_G: 7.6271 D(x): 0.9941 D(G(z)): 0.0023 / 0.0009 Elapsed: 0.21 secs
#  --- Discriminator model stored in DCGAN/output/ckpt_output/dcgan_dis_z100_ep500_12may_newest_newest.pth ---
#  --- Generator model stored in DCGAN/output/ckpt_output/dcgan_gen_z100_ep500_12may_newest_newest.pth ---
# [475/500] [0 / 3] Loss_D: 0.0187 Loss_G: 6.0592 D(x): 0.9930 D(G(z)): 0.0115 / 0.0027 Elapsed: 0.30 secs
#  --- Discriminator model stored in DCGAN/output/ckpt_output/dcgan_dis_z100_ep500_12may_newest_newest.pth ---
#  --- Generator model stored in DCGAN/output/ckpt_output/dcgan_gen_z100_ep500_12may_newest_newest.pth ---
# [476/500] [0 / 3] Loss_D: 0.0127 Loss_G: 6.8659 D(x): 0.9937 D(G(z)): 0.0064 / 0.0013 Elapsed: 0.30 secs
#  --- Discriminator model stored in DCGAN/output/ckpt_output/dcgan_dis_z100_ep500_12may_newest_newest.pth ---
#  --- Generator model stored in DCGAN/output/ckpt_output/dcgan_gen_z100_ep500_12may_newest_newest.pth ---
# [477/500] [0 / 3] Loss_D: 0.0206 Loss_G: 5.9442 D(x): 0.9938 D(G(z)): 0.0141 / 0.0037 Elapsed: 0.31 secs
#  --- Discriminator model stored in DCGAN/output/ckpt_output/dcgan_dis_z100_ep500_12may_newest_newest.pth ---
#  --- Generator model stored in DCGAN/output/ckpt_output/dcgan_gen_z100_ep500_12may_newest_newest.pth ---
# [478/500] [0 / 3] Loss_D: 0.0189 Loss_G: 6.8589 D(x): 0.9872 D(G(z)): 0.0059 / 0.0014 Elapsed: 0.22 secs
#  --- Discriminator model stored in DCGAN/output/ckpt_output/dcgan_dis_z100_ep500_12may_newest_newest.pth ---
#  --- Generator model stored in DCGAN/output/ckpt_output/dcgan_gen_z100_ep500_12may_newest_newest.pth ---
# [479/500] [0 / 3] Loss_D: 0.0280 Loss_G: 5.9405 D(x): 0.9848 D(G(z)): 0.0120 / 0.0031 Elapsed: 0.24 secs
#  --- Discriminator model stored in DCGAN/output/ckpt_output/dcgan_dis_z100_ep500_12may_newest_newest.pth ---
#  --- Generator model stored in DCGAN/output/ckpt_output/dcgan_gen_z100_ep500_12may_newest_newest.pth ---
# [480/500] [0 / 3] Loss_D: 0.0117 Loss_G: 6.4810 D(x): 0.9951 D(G(z)): 0.0068 / 0.0017 Elapsed: 0.29 secs
#  --- Discriminator model stored in DCGAN/output/ckpt_output/dcgan_dis_z100_ep500_12may_newest_newest.pth ---
#  --- Generator model stored in DCGAN/output/ckpt_output/dcgan_gen_z100_ep500_12may_newest_newest.pth ---
# [481/500] [0 / 3] Loss_D: 0.2397 Loss_G: 17.4364 D(x): 0.9993 D(G(z)): 0.1897 / 0.0000 Elapsed: 0.31 secs
#  --- Discriminator model stored in DCGAN/output/ckpt_output/dcgan_dis_z100_ep500_12may_newest_newest.pth ---
#  --- Generator model stored in DCGAN/output/ckpt_output/dcgan_gen_z100_ep500_12may_newest_newest.pth ---
# [482/500] [0 / 3] Loss_D: 0.0020 Loss_G: 18.5104 D(x): 0.9981 D(G(z)): 0.0001 / 0.0003 Elapsed: 0.29 secs
#  --- Discriminator model stored in DCGAN/output/ckpt_output/dcgan_dis_z100_ep500_12may_newest_newest.pth ---
#  --- Generator model stored in DCGAN/output/ckpt_output/dcgan_gen_z100_ep500_12may_newest_newest.pth ---
# [483/500] [0 / 3] Loss_D: 0.4155 Loss_G: 16.6199 D(x): 0.9999 D(G(z)): 0.2708 / 0.0001 Elapsed: 0.29 secs
#  --- Discriminator model stored in DCGAN/output/ckpt_output/dcgan_dis_z100_ep500_12may_newest_newest.pth ---
#  --- Generator model stored in DCGAN/output/ckpt_output/dcgan_gen_z100_ep500_12may_newest_newest.pth ---
# [484/500] [0 / 3] Loss_D: 0.4773 Loss_G: 21.2106 D(x): 0.9976 D(G(z)): 0.1528 / 0.0000 Elapsed: 0.22 secs
#  --- Discriminator model stored in DCGAN/output/ckpt_output/dcgan_dis_z100_ep500_12may_newest_newest.pth ---
#  --- Generator model stored in DCGAN/output/ckpt_output/dcgan_gen_z100_ep500_12may_newest_newest.pth ---
# [485/500] [0 / 3] Loss_D: 0.0332 Loss_G: 14.1839 D(x): 0.9737 D(G(z)): 0.0004 / 0.0006 Elapsed: 0.22 secs
#  --- Discriminator model stored in DCGAN/output/ckpt_output/dcgan_dis_z100_ep500_12may_newest_newest.pth ---
#  --- Generator model stored in DCGAN/output/ckpt_output/dcgan_gen_z100_ep500_12may_newest_newest.pth ---
# [486/500] [0 / 3] Loss_D: 0.0069 Loss_G: 6.4273 D(x): 0.9989 D(G(z)): 0.0057 / 0.0027 Elapsed: 0.29 secs
#  --- Discriminator model stored in DCGAN/output/ckpt_output/dcgan_dis_z100_ep500_12may_newest_newest.pth ---
#  --- Generator model stored in DCGAN/output/ckpt_output/dcgan_gen_z100_ep500_12may_newest_newest.pth ---
# [487/500] [0 / 3] Loss_D: 0.0067 Loss_G: 13.5140 D(x): 0.9935 D(G(z)): 0.0001 / 0.0000 Elapsed: 0.20 secs
#  --- Discriminator model stored in DCGAN/output/ckpt_output/dcgan_dis_z100_ep500_12may_newest_newest.pth ---
#  --- Generator model stored in DCGAN/output/ckpt_output/dcgan_gen_z100_ep500_12may_newest_newest.pth ---
# [488/500] [0 / 3] Loss_D: 0.0150 Loss_G: 5.9324 D(x): 0.9933 D(G(z)): 0.0082 / 0.0057 Elapsed: 0.22 secs
#  --- Discriminator model stored in DCGAN/output/ckpt_output/dcgan_dis_z100_ep500_12may_newest_newest.pth ---
#  --- Generator model stored in DCGAN/output/ckpt_output/dcgan_gen_z100_ep500_12may_newest_newest.pth ---
# [489/500] [0 / 3] Loss_D: 3.1082 Loss_G: 33.5351 D(x): 0.9976 D(G(z)): 0.6652 / 0.0000 Elapsed: 0.29 secs
#  --- Discriminator model stored in DCGAN/output/ckpt_output/dcgan_dis_z100_ep500_12may_newest_newest.pth ---
#  --- Generator model stored in DCGAN/output/ckpt_output/dcgan_gen_z100_ep500_12may_newest_newest.pth ---
# [490/500] [0 / 3] Loss_D: 0.0043 Loss_G: 36.7125 D(x): 0.9957 D(G(z)): 0.0000 / 0.0000 Elapsed: 0.23 secs
#  --- Discriminator model stored in DCGAN/output/ckpt_output/dcgan_dis_z100_ep500_12may_newest_newest.pth ---
#  --- Generator model stored in DCGAN/output/ckpt_output/dcgan_gen_z100_ep500_12may_newest_newest.pth ---
# [491/500] [0 / 3] Loss_D: 0.0002 Loss_G: 27.7833 D(x): 0.9998 D(G(z)): 0.0000 / 0.0000 Elapsed: 0.28 secs
#  --- Discriminator model stored in DCGAN/output/ckpt_output/dcgan_dis_z100_ep500_12may_newest_newest.pth ---
#  --- Generator model stored in DCGAN/output/ckpt_output/dcgan_gen_z100_ep500_12may_newest_newest.pth ---
# [492/500] [0 / 3] Loss_D: 0.0002 Loss_G: 23.0540 D(x): 1.0000 D(G(z)): 0.0001 / 0.0001 Elapsed: 0.23 secs
#  --- Discriminator model stored in DCGAN/output/ckpt_output/dcgan_dis_z100_ep500_12may_newest_newest.pth ---
#  --- Generator model stored in DCGAN/output/ckpt_output/dcgan_gen_z100_ep500_12may_newest_newest.pth ---
# [493/500] [0 / 3] Loss_D: 0.0018 Loss_G: 11.5262 D(x): 0.9999 D(G(z)): 0.0017 / 0.0015 Elapsed: 0.20 secs
#  --- Discriminator model stored in DCGAN/output/ckpt_output/dcgan_dis_z100_ep500_12may_newest_newest.pth ---
#  --- Generator model stored in DCGAN/output/ckpt_output/dcgan_gen_z100_ep500_12may_newest_newest.pth ---
# [494/500] [0 / 3] Loss_D: 0.0004 Loss_G: 15.5000 D(x): 0.9999 D(G(z)): 0.0004 / 0.0000 Elapsed: 0.29 secs
#  --- Discriminator model stored in DCGAN/output/ckpt_output/dcgan_dis_z100_ep500_12may_newest_newest.pth ---
#  --- Generator model stored in DCGAN/output/ckpt_output/dcgan_gen_z100_ep500_12may_newest_newest.pth ---
# [495/500] [0 / 3] Loss_D: 0.0026 Loss_G: 10.5521 D(x): 0.9982 D(G(z)): 0.0008 / 0.0007 Elapsed: 0.22 secs
#  --- Discriminator model stored in DCGAN/output/ckpt_output/dcgan_dis_z100_ep500_12may_newest_newest.pth ---
#  --- Generator model stored in DCGAN/output/ckpt_output/dcgan_gen_z100_ep500_12may_newest_newest.pth ---
# [496/500] [0 / 3] Loss_D: 0.0589 Loss_G: 6.8152 D(x): 0.9982 D(G(z)): 0.0544 / 0.0020 Elapsed: 0.30 secs
#  --- Discriminator model stored in DCGAN/output/ckpt_output/dcgan_dis_z100_ep500_12may_newest_newest.pth ---
#  --- Generator model stored in DCGAN/output/ckpt_output/dcgan_gen_z100_ep500_12may_newest_newest.pth ---
# [497/500] [0 / 3] Loss_D: 0.0193 Loss_G: 6.6823 D(x): 0.9976 D(G(z)): 0.0163 / 0.0023 Elapsed: 0.23 secs
#  --- Discriminator model stored in DCGAN/output/ckpt_output/dcgan_dis_z100_ep500_12may_newest_newest.pth ---
#  --- Generator model stored in DCGAN/output/ckpt_output/dcgan_gen_z100_ep500_12may_newest_newest.pth ---
# [498/500] [0 / 3] Loss_D: 0.0671 Loss_G: 7.4538 D(x): 0.9969 D(G(z)): 0.0595 / 0.0009 Elapsed: 0.21 secs
#  --- Discriminator model stored in DCGAN/output/ckpt_output/dcgan_dis_z100_ep500_12may_newest_newest.pth ---
#  --- Generator model stored in DCGAN/output/ckpt_output/dcgan_gen_z100_ep500_12may_newest_newest.pth ---
# [499/500] [0 / 3] Loss_D: 0.0483 Loss_G: 5.8687 D(x): 0.9653 D(G(z)): 0.0087 / 0.0042 Elapsed: 0.28 secs
#  --- Discriminator model stored in DCGAN/output/ckpt_output/dcgan_dis_z100_ep500_12may_newest_newest.pth ---
#  --- Generator model stored in DCGAN/output/ckpt_output/dcgan_gen_z100_ep500_12may_newest_newest.pth ---
# [500/500] [0 / 3] Loss_D: 0.0205 Loss_G: 7.6496 D(x): 0.9961 D(G(z)): 0.0160 / 0.0016 Elapsed: 0.21 secs
#  --- Discriminator model stored in DCGAN/output/ckpt_output/dcgan_dis_z100_ep500_12may_newest_newest.pth ---
#  --- Generator model stored in DCGAN/output/ckpt_output/dcgan_gen_z100_ep500_12may_newest_newest.pth ---

# %%
UAS_Deep_Learning/DCGAN/output/image_gen
